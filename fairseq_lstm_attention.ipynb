# %%
import json

import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

from pprint import pprint

import plotly.io as pio
pio.renderers.default='jupyterlab'  # notebook doesn't work check https://plotly.com/python/renderers/
pd.options.display.max_columns = 100
pd.options.display.max_rows = 300

# %%
mats = pd.read_csv("in/tables/MATERIALS_FOR_CLASSIFICATION_CLEAN.csv")
cats = pd.read_csv("in/tables/MATERIAL_CATEGORY_FOR_CLASSIFICATION.csv")

df = pd.merge(mats,cats,on=["MATERIAL_ODS_ID","SHOP"])

def create_category_dict(df):
    return df.groupby("CATEGORY_ID").CATEGORY_PATH.unique().to_dict()
category_dict = create_category_dict(df)

# should be applied after category_decoder_dict
df = df[~df.MATERIAL_ID.duplicated()].reset_index(drop=True).copy()

for k,v in category_dict.items():
    df.loc[df.CATEGORY_ID == k,"CATEGORY_PATH_FIX"] = v[0]

# %%
subset = df.copy()

# %%
subset.CATEGORY_PATH = subset.CATEGORY_PATH.str.split(" > ").apply(lambda x: " > ".join(x[1:]))

# %%
from sklearn.preprocessing import LabelEncoder

# encode matcat names as integer values because transformer models do not accept strings
subset['CATEGORY_SEQ_TOKENS'] = subset['CATEGORY_PATH'].str.split(" > ")
unique_tokens = []
for i in subset['CATEGORY_SEQ_TOKENS']:
    unique_tokens.extend(i)
    
label_enc = LabelEncoder()
labeled_tokens = label_enc.fit_transform(unique_tokens)

tokens_seq = []
pos=0
for i in subset['CATEGORY_SEQ_TOKENS']:
    tokens_seq.append(labeled_tokens[pos:pos+len(i)])
    pos+=len(i)
    
# new from transformers
int_tokens_seq = [str(i).strip("[ ]").split(" ") for i in tokens_seq]

# %%
for i in int_tokens_seq:
    try:
        for _ in range(10): del i[i.index("")]
    except:
        continue

# %%
subset['CATEGORY_SEQ'] = tokens_seq

# %%
subset["CATEGORY_SEQ_STR"] = subset.CATEGORY_SEQ.apply(lambda x: " ".join(x.astype(str)))

# %%
def prepare_MT_data(row):
    return row["NAME_BRIEF"] + " \t " + row["CATEGORY_SEQ_STR"]

# %%
subset["text"] = subset.apply(prepare_MT_data, axis=1)

# %%
# test_categories = df.CATEGORY_ID.value_counts().reset_index().query("CATEGORY_ID > 20")["index"].values
# df = df.query("CATEGORY_ID in @test_categories").copy()

def remove_too_small_categories(df, how_many=20):
    """
    Remove all categories small than @how_many, 
    because it is unsufficient to add them to classification.
    These categories need to be evaluated in final testing.
    """
    too_small_cats = df.CATEGORY_ID.value_counts().reset_index().query("CATEGORY_ID<@how_many")["index"].unique()
    indices = df[df.CATEGORY_ID.isin(too_small_cats)].index
    small_cat_df = df.iloc[indices].copy()
    print(f"Len of df before: {df.shape[0]}")
    df.drop(indices, inplace=True)
    print(f"Len of df after: {df.shape[0]}")
    return small_cat_df

too_small_categories_df = remove_too_small_categories(subset)
# Out:
# Len of df before: 240998
# Len of df after: 240998

# %%
from sklearn.model_selection import train_test_split

def create_datasets(df, stratify_by="CATEGORY_ID",make_valid=None, random_state=1):
    """
    Create train/test, possibly also validation dataset.
    If make_valid=True, then returns df,list(df,df)
    """
    train, test = train_test_split(df.reset_index(drop=True), 
                                   stratify=df[stratify_by],
                                   test_size=0.3, 
                                   random_state=random_state)
    if make_valid:
        test = train_test_split(test.reset_index(drop=True),
                                test_size=0.3,
                                random_state=random_state)
    
    return train, test

def over_sample(df, categories_smaller=100):
    """
    Oversample for really small categories
    """
    new_df = pd.DataFrame()
    # smaller categories
    small_categories = (df.CATEGORY_ID
                        .value_counts()
                        .reset_index()
                        .query("CATEGORY_ID < 100"))
    
    for _,cat_id, count in small_categories.itertuples():
        append_another = categories_smaller-count
        df_cat = df.query("CATEGORY_ID == @cat_id")
        new_df = new_df.append(df_cat.iloc[np.random.randint(df_cat.shape[0],size=append_another)])
    
    print(f"Appending {new_df.shape[0]} of new samples")
    return pd.concat([df,new_df])

# %%
subset = subset[["MATERIAL_ID","NAME_BRIEF","text","CATEGORY_SEQ", "CATEGORY_PATH", "CATEGORY_ID"]].copy()
# subset = subset[subset.NAME.str.len() >9].copy().reset_index()
# subset.NAME = subset.NAME.str.lower()
# subset.NAME = subset.NAME.str.replace('\n', '')

# %%
train, test = create_datasets(subset)
test, validation = create_datasets(test)

# %%
train.shape, test.shape, validation.shape
# Out:
# ((168698, 6), (50610, 6), (21690, 6))

# %%
import csv
def save_set(subset,name):
    subset[["text"]].to_csv(f'data/mt/categorizer.cs_cat.{name}.tsv', index=False, sep="$", header=False,
                           quoting = csv.QUOTE_NONE, escapechar = ' ')
    subset[["NAME_BRIEF"]].to_csv(f'data/mt/categorizer.cs_cat.{name}.tok.cs', index=False, sep="$", header=False,
                           quoting = csv.QUOTE_NONE, escapechar = ' ')
    subset[["CATEGORY_SEQ"]].to_csv(f'data/mt/categorizer.cs_cat.{name}.tok.cat', index=False, sep="$", header=False,
                           quoting = csv.QUOTE_NONE, escapechar = ' ')

# %%
# !mkdir -p data/mt

# %%
save_set(train, "train")
save_set(test, "test")
save_set(validation, "valid")

# %%
# !fairseq-preprocess \
    --source-lang cs \
    --target-lang cat \
    --trainpref data/mt/categorizer.cs_cat.train.tok \
    --validpref data/mt/categorizer.cs_cat.valid.tok \
    --testpref data/mt/categorizer.cs_cat.test.tok \
    --destdir data/mt-bin \
    --thresholdsrc 3 \
    --thresholdtgt 3
# Out:
# 2022-01-02 17:46:07 | INFO | fairseq_cli.preprocess | Namespace(align_suffix=None, alignfile=None, all_gather_list_size=16384, bf16=False, bpe=None, checkpoint_shard_count=1, checkpoint_suffix='', cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='data/mt-bin', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer=None, padding_factor=8, profile=False, quantization_config_path=None, scoring='bleu', seed=1, source_lang='cs', srcdict=None, target_lang='cat', task='translation', tensorboard_logdir=None, testpref='data/mt/categorizer.cs_cat.test.tok', tgtdict=None, threshold_loss_scale=None, thresholdsrc=3, thresholdtgt=3, tokenizer=None, tpu=False, trainpref='data/mt/categorizer.cs_cat.train.tok', user_dir=None, validpref='data/mt/categorizer.cs_cat.valid.tok', workers=1)
# 2022-01-02 17:46:23 | INFO | fairseq_cli.preprocess | [cs] Dictionary: 22888 types
# 2022-01-02 17:46:43 | INFO | fairseq_cli.preprocess | [cs] data/mt/categorizer.cs_cat.train.tok.cs: 168698 sents, 4294289 tokens, 0.499% replaced by <unk>
# 2022-01-02 17:46:43 | INFO | fairseq_cli.preprocess | [cs] Dictionary: 22888 types
# 2022-01-02 17:46:45 | INFO | fairseq_cli.preprocess | [cs] data/mt/categorizer.cs_cat.valid.tok.cs: 21690 sents, 551425 tokens, 0.76% replaced by <unk>
# 2022-01-02 17:46:45 | INFO | fairseq_cli.preprocess | [cs] Dictionary: 22888 types
# 2022-01-02 17:46:51 | INFO | fairseq_cli.preprocess | [cs] data/mt/categorizer.cs_cat.test.tok.cs: 50610 sents, 1291409 tokens, 0.752% replaced by <unk>
# 2022-01-02 17:46:51 | INFO | fairseq_cli.preprocess | [cat] Dictionary: 472 types
# 2022-01-02 17:46:55 | INFO | fairseq_cli.preprocess | [cat] data/mt/categorizer.cs_cat.train.tok.cat: 168698 sents, 606520 tokens, 0.0% replaced by <unk>
# 2022-01-02 17:46:55 | INFO | fairseq_cli.preprocess | [cat] Dictionary: 472 types
# 2022-01-02 17:46:55 | INFO | fairseq_cli.preprocess | [cat] data/mt/categorizer.cs_cat.valid.tok.cat: 21690 sents, 77989 tokens, 0.0% replaced by <unk>
# 2022-01-02 17:46:55 | INFO | fairseq_cli.preprocess | [cat] Dictionary: 472 types
# 2022-01-02 17:46:57 | INFO | fairseq_cli.preprocess | [cat] data/mt/categorizer.cs_cat.test.tok.cat: 50610 sents, 181930 tokens, 0.0% replaced by <unk>
# 2022-01-02 17:46:57 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to data/mt-bin

# %%
# pip install tensorboardX tensorflow keras==2.6
# Out:
# Collecting tensorboardX
#   Using cached tensorboardX-2.4-py2.py3-none-any.whl (124 kB)
# Collecting tensorflow
#   Downloading tensorflow-2.7.0-cp38-cp38-manylinux2010_x86_64.whl (489.6 MB)
#      |███████████████████▍            | 296.6 MB 133.6 MB/s eta 0:00:02
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 489.6 MB 20 kB/s /s eta 0:00:01
# Collecting keras==2.6
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 118.0 MB/s eta 0:00:01
# Requirement already satisfied: protobuf>=3.8.0 in /home/default/lib/python3.8/site-packages (from tensorboardX) (3.17.2)
# Requirement already satisfied: numpy in /home/default/lib/python3.8/site-packages (from tensorboardX) (1.20.3)
# Requirement already satisfied: six>=1.9 in /home/default/lib/python3.8/site-packages (from protobuf>=3.8.0->tensorboardX) (1.16.0)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 12.2 MB/s  eta 0:00:01
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.13.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (84 kB)
#      |████████████████████████████████| 84 kB 10.2 MB/s  eta 0:00:01
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 4.2 MB/s s eta 0:00:01
# Collecting absl-py>=0.4.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 122.2 MB/s eta 0:00:01
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 121.1 MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 117.2 MB/s eta 0:00:01
# Requirement already satisfied: h5py>=2.9.0 in /home/default/lib/python3.8/site-packages (from tensorflow) (3.2.1)
# Collecting wheel<1.0,>=0.32.0
#   Downloading wheel-0.37.0-py2.py3-none-any.whl (35 kB)
# Collecting libclang>=9.0.1
#   Downloading libclang-12.0.0-py2.py3-none-manylinux1_x86_64.whl (13.4 MB)
#      |████████████████████████████████| 13.4 MB 117.4 MB/s eta 0:00:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 12.4 MB/s  eta 0:00:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.41.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 65.7 MB/s eta 0:00:01
# Collecting tensorflow
#   Downloading tensorflow-2.6.2-cp38-cp38-manylinux2010_x86_64.whl (458.4 MB)
#      |████████████████████▍           | 292.0 MB 133.1 MB/s eta 0:00:02   |██▉                             | 41.2 MB 18.5 MB/s eta 0:00:23
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 458.4 MB 23 kB/s /s eta 0:00:01
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 85.0 MB/s eta 0:00:01
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp38-cp38-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 119.4 MB/s eta 0:00:01
# Collecting six>=1.9
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 111.2 MB/s eta 0:00:01
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 123.4 MB/s eta 0:00:01
# Collecting numpy
#   Downloading numpy-1.19.5-cp38-cp38-manylinux2010_x86_64.whl (14.9 MB)
#      |████████████████████████████████| 14.9 MB 94.0 MB/s eta 0:00:01
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/default/lib/python3.8/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.0.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 21.0 MB/s  eta 0:00:01
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 117.9 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 122.8 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /home/default/lib/python3.8/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (2.25.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/default/lib/python3.8/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow) (57.0.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 110.5 MB/s eta 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 114.9 MB/s eta 0:00:01
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/default/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (1.3.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 16.2 MB/s  eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /home/default/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/default/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/default/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/default/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/default/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow) (3.1.1)
# Using legacy 'setup.py install' for clang, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for termcolor, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for wrapt, since package 'wheel' is not installed.
# Installing collected packages: pyasn1, six, rsa, pyasn1-modules, cachetools, google-auth, wheel, tensorboard-plugin-wit, tensorboard-data-server, numpy, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, typing-extensions, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, clang, astunparse, tensorflow, tensorboardX
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
#     Running setup.py install for wrapt ... done
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.0
#     Uninstalling typing-extensions-3.10.0.0:
#       Successfully uninstalled typing-extensions-3.10.0.0
#     Running setup.py install for termcolor ... done
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.2.1
#     Uninstalling h5py-3.2.1:
#       Successfully uninstalled h5py-3.2.1
#     Running setup.py install for clang ... done
# Successfully installed absl-py-0.15.0 astunparse-1.6.3 cachetools-4.2.4 clang-5.0 flatbuffers-1.12 gast-0.4.0 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.41.1 h5py-3.1.0 keras-2.6.0 keras-preprocessing-1.1.2 markdown-3.3.4 numpy-1.19.5 opt-einsum-3.3.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.7.2 six-1.15.0 tensorboard-2.6.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorboardX-2.4 tensorflow-2.6.2 tensorflow-estimator-2.6.0 termcolor-1.1.0 typing-extensions-3.7.4.3 wheel-0.37.0 wrapt-1.12.1
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/default/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !fairseq-train \
    data/mt-bin \
    --arch lstm \
    --share-decoder-input-output-embed \
    --optimizer adam \
    --save-dir data/mt-ckpt \
    --tokenizer moses \
    --decoder-hidden-size 256 \
    --encoder-hidden-size 256 \
    --dropout 0.2 \
    --lr 1.0e-3 \
    --max-tokens 4096
# Out:
# 2022-01-02 18:05:23 | INFO | fairseq_cli.train | Namespace(adam_betas='(0.9, 0.999)', adam_eps=1e-08, adaptive_softmax_cutoff='10000,50000,200000', all_gather_list_size=16384, arch='lstm', batch_size=None, batch_size_valid=None, best_checkpoint_metric='loss', bf16=False, bpe=None, broadcast_buffers=False, bucket_cap_mb=25, checkpoint_shard_count=1, checkpoint_suffix='', clip_norm=0.0, cpu=False, criterion='cross_entropy', curriculum=0, data='data/mt-bin', data_buffer_size=10, dataset_impl=None, ddp_backend='c10d', decoder_attention='1', decoder_dropout_in=0.2, decoder_dropout_out=0.2, decoder_embed_dim=512, decoder_embed_path=None, decoder_freeze_embed=False, decoder_hidden_size=256, decoder_layers=1, decoder_out_embed_dim=512, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_num_procs=0, distributed_port=-1, distributed_rank=0, distributed_world_size=1, distributed_wrapper='DDP', dropout=0.2, empty_cache_freq=0, encoder_bidirectional=False, encoder_dropout_in=0.2, encoder_dropout_out=0.2, encoder_embed_dim=512, encoder_embed_path=None, encoder_freeze_embed=False, encoder_hidden_size=256, encoder_layers=1, eval_bleu=False, eval_bleu_args=None, eval_bleu_detok='space', eval_bleu_detok_args=None, eval_bleu_print_samples=False, eval_bleu_remove_bpe=None, eval_tokenized_bleu=False, fast_stat_sync=False, find_unused_parameters=False, finetune_from_model=None, fix_batches_to_gpus=False, fixed_validation_seed=None, force_anneal=None, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', keep_best_checkpoints=-1, keep_interval_updates=-1, keep_last_epochs=-1, left_pad_source='True', left_pad_target='False', load_alignments=False, localsgd_frequency=3, log_format=None, log_interval=100, lr=[0.001], lr_scheduler='fixed', lr_shrink=0.1, max_epoch=0, max_source_positions=1024, max_target_positions=1024, max_tokens=4096, max_tokens_valid=4096, max_update=0, maximize_best_checkpoint_metric=False, memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=-1.0, model_parallel_size=1, moses_no_dash_splits=False, moses_no_escape=False, moses_source_lang=None, moses_target_lang=None, no_epoch_checkpoints=False, no_last_checkpoints=False, no_progress_bar=False, no_save=False, no_save_optimizer_state=False, no_seed_provided=False, nprocs_per_node=1, num_batch_buckets=0, num_shards=1, num_workers=1, optimizer='adam', optimizer_overrides='{}', patience=-1, pipeline_balance=None, pipeline_checkpoint='never', pipeline_chunks=0, pipeline_decoder_balance=None, pipeline_decoder_devices=None, pipeline_devices=None, pipeline_encoder_balance=None, pipeline_encoder_devices=None, pipeline_model_parallel=False, profile=False, quantization_config_path=None, required_batch_size_multiple=8, required_seq_len_multiple=1, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='data/mt-ckpt', save_interval=1, save_interval_updates=0, scoring='bleu', seed=1, sentence_avg=False, shard_id=0, share_all_embeddings=False, share_decoder_input_output_embed=True, skip_invalid_size_inputs_valid_test=False, slowmo_algorithm='LocalSGD', slowmo_momentum=None, source_lang=None, stop_time_hours=0, target_lang=None, task='translation', tensorboard_logdir=None, threshold_loss_scale=None, tokenizer='moses', tpu=False, train_subset='train', truncate_source=False, update_freq=[1], upsample_primary=1, use_bmuf=False, use_old_adam=False, user_dir=None, valid_subset='valid', validate_after_updates=0, validate_interval=1, validate_interval_updates=0, warmup_updates=0, weight_decay=0.0, zero_sharding='none')
# 2022-01-02 18:05:23 | INFO | fairseq.tasks.translation | [cs] dictionary: 22888 types
# 2022-01-02 18:05:23 | INFO | fairseq.tasks.translation | [cat] dictionary: 472 types
# 2022-01-02 18:05:23 | INFO | fairseq.data.data_utils | loaded 21690 examples from: data/mt-bin/valid.cs-cat.cs
# 2022-01-02 18:05:23 | INFO | fairseq.data.data_utils | loaded 21690 examples from: data/mt-bin/valid.cs-cat.cat
# 2022-01-02 18:05:23 | INFO | fairseq.tasks.translation | data/mt-bin valid cs-cat 21690 examples
# 2022-01-02 18:05:23 | INFO | fairseq_cli.train | LSTMModel(
#   (encoder): LSTMEncoder(
#     (dropout_in_module): FairseqDropout()
#     (dropout_out_module): FairseqDropout()
#     (embed_tokens): Embedding(22888, 512, padding_idx=1)
#     (lstm): LSTM(512, 256)
#   )
#   (decoder): LSTMDecoder(
#     (dropout_in_module): FairseqDropout()
#     (dropout_out_module): FairseqDropout()
#     (embed_tokens): Embedding(472, 512, padding_idx=1)
#     (layers): ModuleList(
#       (0): LSTMCell(768, 256)
#     )
#     (attention): AttentionLayer(
#       (input_proj): Linear(in_features=256, out_features=256, bias=False)
#       (output_proj): Linear(in_features=512, out_features=256, bias=False)
#     )
#     (additional_fc): Linear(in_features=256, out_features=512, bias=True)
#   )
# )
# 2022-01-02 18:05:23 | INFO | fairseq_cli.train | task: translation (TranslationTask)
# 2022-01-02 18:05:23 | INFO | fairseq_cli.train | model: lstm (LSTMModel)
# 2022-01-02 18:05:23 | INFO | fairseq_cli.train | criterion: cross_entropy (CrossEntropyCriterion)
# 2022-01-02 18:05:23 | INFO | fairseq_cli.train | num. model params: 14127616 (num. trained: 14127616)
# 2022-01-02 18:05:23 | INFO | fairseq.trainer | detected shared parameter: decoder.attention.input_proj.bias <- decoder.attention.output_proj.bias
# 2022-01-02 18:05:23 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2022-01-02 18:05:23 | INFO | fairseq_cli.train | max tokens per GPU = 4096 and max sentences per GPU = None
# 2022-01-02 18:05:23 | INFO | fairseq.trainer | no existing checkpoint found data/mt-ckpt/checkpoint_last.pt
# 2022-01-02 18:05:23 | INFO | fairseq.trainer | loading train data for epoch 1
# 2022-01-02 18:05:23 | INFO | fairseq.data.data_utils | loaded 168698 examples from: data/mt-bin/train.cs-cat.cs
# 2022-01-02 18:05:23 | INFO | fairseq.data.data_utils | loaded 168698 examples from: data/mt-bin/train.cs-cat.cat
# 2022-01-02 18:05:23 | INFO | fairseq.tasks.translation | data/mt-bin train cs-cat 168698 examples
# epoch 001:   0%|                                       | 0/1080 [00:00<?, ?it/s]2022-01-02 18:05:23 | INFO | fairseq.trainer | begin training epoch 1
# epoch 001: 100%|▉| 1079/1080 [07:02<00:00,  2.42it/s, loss=0.513, ppl=1.43, wps=2022-01-02 18:12:26 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 001 | valid on 'valid' subset:   0%|              | 0/140 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:   1%|      | 1/140 [00:00<01:14,  1.87it/s]
# epoch 001 | valid on 'valid' subset:   1%|      | 2/140 [00:00<00:47,  2.92it/s]
# epoch 001 | valid on 'valid' subset:   2%|▏     | 3/140 [00:00<00:37,  3.63it/s]
# epoch 001 | valid on 'valid' subset:   3%|▏     | 4/140 [00:01<00:29,  4.58it/s]
# epoch 001 | valid on 'valid' subset:   4%|▏     | 5/140 [00:01<00:27,  4.82it/s]
# epoch 001 | valid on 'valid' subset:   4%|▎     | 6/140 [00:01<00:23,  5.81it/s]
# epoch 001 | valid on 'valid' subset:   5%|▎     | 7/140 [00:01<00:20,  6.48it/s]
# epoch 001 | valid on 'valid' subset:   6%|▎     | 8/140 [00:01<00:20,  6.39it/s]
# epoch 001 | valid on 'valid' subset:   6%|▍     | 9/140 [00:01<00:19,  6.87it/s]
# epoch 001 | valid on 'valid' subset:   7%|▎    | 10/140 [00:01<00:17,  7.59it/s]
# epoch 001 | valid on 'valid' subset:   8%|▍    | 11/140 [00:01<00:16,  8.06it/s]
# epoch 001 | valid on 'valid' subset:   9%|▍    | 13/140 [00:02<00:14,  8.75it/s]
# epoch 001 | valid on 'valid' subset:  11%|▌    | 15/140 [00:02<00:13,  9.41it/s]
# epoch 001 | valid on 'valid' subset:  12%|▌    | 17/140 [00:02<00:12,  9.67it/s]
# epoch 001 | valid on 'valid' subset:  14%|▋    | 19/140 [00:02<00:12,  9.98it/s]
# epoch 001 | valid on 'valid' subset:  15%|▊    | 21/140 [00:02<00:10, 11.45it/s]
# epoch 001 | valid on 'valid' subset:  16%|▊    | 23/140 [00:03<00:10, 11.30it/s]
# epoch 001 | valid on 'valid' subset:  18%|▉    | 25/140 [00:03<00:09, 12.56it/s]
# epoch 001 | valid on 'valid' subset:  19%|▉    | 27/140 [00:03<00:09, 11.83it/s]
# epoch 001 | valid on 'valid' subset:  21%|█    | 29/140 [00:03<00:09, 11.59it/s]
# epoch 001 | valid on 'valid' subset:  22%|█    | 31/140 [00:03<00:08, 12.66it/s]
# epoch 001 | valid on 'valid' subset:  24%|█▏   | 33/140 [00:03<00:08, 12.23it/s]
# epoch 001 | valid on 'valid' subset:  25%|█▎   | 35/140 [00:03<00:08, 13.12it/s]
# epoch 001 | valid on 'valid' subset:  26%|█▎   | 37/140 [00:04<00:08, 12.42it/s]
# epoch 001 | valid on 'valid' subset:  28%|█▍   | 39/140 [00:04<00:07, 13.59it/s]
# epoch 001 | valid on 'valid' subset:  29%|█▍   | 41/140 [00:04<00:07, 12.95it/s]
# epoch 001 | valid on 'valid' subset:  31%|█▌   | 43/140 [00:04<00:06, 13.88it/s]
# epoch 001 | valid on 'valid' subset:  32%|█▌   | 45/140 [00:04<00:06, 14.71it/s]
# epoch 001 | valid on 'valid' subset:  34%|█▋   | 47/140 [00:04<00:06, 13.64it/s]
# epoch 001 | valid on 'valid' subset:  35%|█▊   | 49/140 [00:04<00:06, 14.48it/s]
# epoch 001 | valid on 'valid' subset:  36%|█▊   | 51/140 [00:05<00:06, 13.54it/s]
# epoch 001 | valid on 'valid' subset:  38%|█▉   | 53/140 [00:05<00:06, 14.38it/s]
# epoch 001 | valid on 'valid' subset:  39%|█▉   | 55/140 [00:05<00:05, 15.02it/s]
# epoch 001 | valid on 'valid' subset:  41%|██   | 57/140 [00:05<00:06, 13.72it/s]
# epoch 001 | valid on 'valid' subset:  42%|██   | 59/140 [00:05<00:05, 14.54it/s]
# epoch 001 | valid on 'valid' subset:  44%|██▏  | 61/140 [00:05<00:06, 12.85it/s]
# epoch 001 | valid on 'valid' subset:  45%|██▎  | 63/140 [00:06<00:06, 12.48it/s]
# epoch 001 | valid on 'valid' subset:  46%|██▎  | 65/140 [00:06<00:05, 13.52it/s]
# epoch 001 | valid on 'valid' subset:  48%|██▍  | 67/140 [00:06<00:05, 12.67it/s]
# epoch 001 | valid on 'valid' subset:  49%|██▍  | 69/140 [00:06<00:05, 13.75it/s]
# epoch 001 | valid on 'valid' subset:  51%|██▌  | 71/140 [00:06<00:04, 14.57it/s]
# epoch 001 | valid on 'valid' subset:  52%|██▌  | 73/140 [00:06<00:04, 13.62it/s]
# epoch 001 | valid on 'valid' subset:  54%|██▋  | 75/140 [00:06<00:04, 14.48it/s]
# epoch 001 | valid on 'valid' subset:  55%|██▊  | 77/140 [00:07<00:04, 13.15it/s]
# epoch 001 | valid on 'valid' subset:  56%|██▊  | 79/140 [00:07<00:04, 13.79it/s]
# epoch 001 | valid on 'valid' subset:  58%|██▉  | 81/140 [00:07<00:04, 12.64it/s]
# epoch 001 | valid on 'valid' subset:  59%|██▉  | 83/140 [00:07<00:04, 12.00it/s]
# epoch 001 | valid on 'valid' subset:  61%|███  | 85/140 [00:07<00:04, 11.53it/s]
# epoch 001 | valid on 'valid' subset:  62%|███  | 87/140 [00:07<00:04, 12.58it/s]
# epoch 001 | valid on 'valid' subset:  64%|███▏ | 89/140 [00:08<00:04, 11.97it/s]
# epoch 001 | valid on 'valid' subset:  65%|███▎ | 91/140 [00:08<00:03, 12.79it/s]
# epoch 001 | valid on 'valid' subset:  66%|███▎ | 93/140 [00:08<00:03, 12.10it/s]
# epoch 001 | valid on 'valid' subset:  68%|███▍ | 95/140 [00:08<00:03, 11.75it/s]
# epoch 001 | valid on 'valid' subset:  69%|███▍ | 97/140 [00:08<00:03, 12.88it/s]
# epoch 001 | valid on 'valid' subset:  71%|███▌ | 99/140 [00:08<00:03, 12.48it/s]
# epoch 001 | valid on 'valid' subset:  72%|██▉ | 101/140 [00:08<00:02, 13.52it/s]
# epoch 001 | valid on 'valid' subset:  74%|██▉ | 103/140 [00:09<00:02, 14.26it/s]
# epoch 001 | valid on 'valid' subset:  75%|███ | 105/140 [00:09<00:02, 13.28it/s]
# epoch 001 | valid on 'valid' subset:  76%|███ | 107/140 [00:09<00:02, 12.25it/s]
# epoch 001 | valid on 'valid' subset:  78%|███ | 109/140 [00:09<00:02, 13.25it/s]
# epoch 001 | valid on 'valid' subset:  79%|███▏| 111/140 [00:09<00:02, 12.60it/s]
# epoch 001 | valid on 'valid' subset:  81%|███▏| 113/140 [00:09<00:01, 13.63it/s]
# epoch 001 | valid on 'valid' subset:  82%|███▎| 115/140 [00:10<00:01, 12.81it/s]
# epoch 001 | valid on 'valid' subset:  84%|███▎| 117/140 [00:10<00:01, 13.95it/s]
# epoch 001 | valid on 'valid' subset:  85%|███▍| 119/140 [00:10<00:01, 14.68it/s]
# epoch 001 | valid on 'valid' subset:  86%|███▍| 121/140 [00:10<00:01, 13.58it/s]
# epoch 001 | valid on 'valid' subset:  88%|███▌| 123/140 [00:10<00:01, 14.43it/s]
# epoch 001 | valid on 'valid' subset:  89%|███▌| 125/140 [00:10<00:01, 13.39it/s]
# epoch 001 | valid on 'valid' subset:  91%|███▋| 127/140 [00:10<00:00, 14.48it/s]
# epoch 001 | valid on 'valid' subset:  92%|███▋| 129/140 [00:10<00:00, 15.42it/s]
# epoch 001 | valid on 'valid' subset:  94%|███▋| 131/140 [00:11<00:00, 14.09it/s]
# epoch 001 | valid on 'valid' subset:  95%|███▊| 133/140 [00:11<00:00, 14.91it/s]
# epoch 001 | valid on 'valid' subset:  96%|███▊| 135/140 [00:11<00:00, 15.87it/s]
# epoch 001 | valid on 'valid' subset:  98%|███▉| 137/140 [00:11<00:00, 16.53it/s]
# epoch 001 | valid on 'valid' subset:  99%|███▉| 139/140 [00:11<00:00, 16.96it/s]
#                                                                                 2022-01-02 18:12:38 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 0.404 | ppl 1.32 | wps 6829.1 | wpb 557.1 | bsz 154.9 | num_updates 1080
# 2022-01-02 18:12:38 | INFO | fairseq_cli.train | begin save checkpoint
# 2022-01-02 18:12:39 | INFO | fairseq.checkpoint_utils | saved checkpoint data/mt-ckpt/checkpoint1.pt (epoch 1 @ 1080 updates, score 0.404) (writing took 1.4734722450375557 seconds)
# 2022-01-02 18:12:39 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2022-01-02 18:12:39 | INFO | train | epoch 001 | loss 1.152 | ppl 2.22 | wps 1390.4 | ups 2.48 | wpb 561.6 | bsz 156.2 | num_updates 1080 | lr 0.001 | gnorm 0.974 | train_wall 415 | wall 436
# epoch 002:   0%|                                       | 0/1080 [00:00<?, ?it/s]2022-01-02 18:12:39 | INFO | fairseq.trainer | begin training epoch 2
# epoch 002: 100%|▉| 1079/1080 [07:14<00:00,  2.39it/s, loss=0.335, ppl=1.26, wps=2022-01-02 18:19:55 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 002 | valid on 'valid' subset:   0%|              | 0/140 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:   1%|      | 1/140 [00:00<01:16,  1.81it/s]
# epoch 002 | valid on 'valid' subset:   1%|      | 2/140 [00:00<00:53,  2.57it/s]
# epoch 002 | valid on 'valid' subset:   2%|▏     | 3/140 [00:00<00:37,  3.65it/s]
# epoch 002 | valid on 'valid' subset:   3%|▏     | 4/140 [00:01<00:32,  4.23it/s]
# epoch 002 | valid on 'valid' subset:   4%|▏     | 5/140 [00:01<00:26,  5.14it/s]
# epoch 002 | valid on 'valid' subset:   4%|▎     | 6/140 [00:01<00:25,  5.34it/s]
# epoch 002 | valid on 'valid' subset:   5%|▎     | 7/140 [00:01<00:21,  6.11it/s]
# epoch 002 | valid on 'valid' subset:   6%|▎     | 8/140 [00:01<00:19,  6.87it/s]
# epoch 002 | valid on 'valid' subset:   6%|▍     | 9/140 [00:01<00:17,  7.52it/s]
# epoch 002 | valid on 'valid' subset:   7%|▎    | 10/140 [00:01<00:16,  8.01it/s]
# epoch 002 | valid on 'valid' subset:   8%|▍    | 11/140 [00:02<00:17,  7.38it/s]
# epoch 002 | valid on 'valid' subset:   9%|▍    | 13/140 [00:02<00:13,  9.73it/s]
# epoch 002 | valid on 'valid' subset:  11%|▌    | 15/140 [00:02<00:12, 10.16it/s]
# epoch 002 | valid on 'valid' subset:  12%|▌    | 17/140 [00:02<00:11, 10.33it/s]
# epoch 002 | valid on 'valid' subset:  14%|▋    | 19/140 [00:02<00:10, 11.69it/s]
# epoch 002 | valid on 'valid' subset:  15%|▊    | 21/140 [00:02<00:10, 11.32it/s]
# epoch 002 | valid on 'valid' subset:  16%|▊    | 23/140 [00:03<00:10, 11.25it/s]
# epoch 002 | valid on 'valid' subset:  18%|▉    | 25/140 [00:03<00:09, 12.12it/s]
# epoch 002 | valid on 'valid' subset:  19%|▉    | 27/140 [00:03<00:09, 11.46it/s]
# epoch 002 | valid on 'valid' subset:  21%|█    | 29/140 [00:03<00:10, 10.97it/s]
# epoch 002 | valid on 'valid' subset:  22%|█    | 31/140 [00:03<00:10, 10.69it/s]
# epoch 002 | valid on 'valid' subset:  24%|█▏   | 33/140 [00:03<00:10, 10.55it/s]
# epoch 002 | valid on 'valid' subset:  25%|█▎   | 35/140 [00:04<00:09, 10.53it/s]
# epoch 002 | valid on 'valid' subset:  26%|█▎   | 37/140 [00:04<00:09, 10.55it/s]
# epoch 002 | valid on 'valid' subset:  28%|█▍   | 39/140 [00:04<00:08, 11.64it/s]
# epoch 002 | valid on 'valid' subset:  29%|█▍   | 41/140 [00:04<00:08, 11.32it/s]
# epoch 002 | valid on 'valid' subset:  31%|█▌   | 43/140 [00:04<00:08, 11.05it/s]
# epoch 002 | valid on 'valid' subset:  32%|█▌   | 45/140 [00:04<00:07, 12.41it/s]
# epoch 002 | valid on 'valid' subset:  34%|█▋   | 47/140 [00:05<00:07, 12.13it/s]
# epoch 002 | valid on 'valid' subset:  35%|█▊   | 49/140 [00:05<00:06, 13.22it/s]
# epoch 002 | valid on 'valid' subset:  36%|█▊   | 51/140 [00:05<00:06, 14.28it/s]
# epoch 002 | valid on 'valid' subset:  38%|█▉   | 53/140 [00:05<00:06, 13.24it/s]
# epoch 002 | valid on 'valid' subset:  39%|█▉   | 55/140 [00:05<00:06, 14.12it/s]
# epoch 002 | valid on 'valid' subset:  41%|██   | 57/140 [00:05<00:06, 12.99it/s]
# epoch 002 | valid on 'valid' subset:  42%|██   | 59/140 [00:05<00:05, 14.06it/s]
# epoch 002 | valid on 'valid' subset:  44%|██▏  | 61/140 [00:06<00:06, 13.06it/s]
# epoch 002 | valid on 'valid' subset:  45%|██▎  | 63/140 [00:06<00:05, 14.12it/s]
# epoch 002 | valid on 'valid' subset:  46%|██▎  | 65/140 [00:06<00:05, 13.05it/s]
# epoch 002 | valid on 'valid' subset:  48%|██▍  | 67/140 [00:06<00:05, 13.84it/s]
# epoch 002 | valid on 'valid' subset:  49%|██▍  | 69/140 [00:06<00:05, 12.44it/s]
# epoch 002 | valid on 'valid' subset:  51%|██▌  | 71/140 [00:06<00:05, 11.73it/s]
# epoch 002 | valid on 'valid' subset:  52%|██▌  | 73/140 [00:07<00:05, 11.53it/s]
# epoch 002 | valid on 'valid' subset:  54%|██▋  | 75/140 [00:07<00:05, 12.74it/s]
# epoch 002 | valid on 'valid' subset:  55%|██▊  | 77/140 [00:07<00:04, 13.53it/s]
# epoch 002 | valid on 'valid' subset:  56%|██▊  | 79/140 [00:07<00:04, 12.88it/s]
# epoch 002 | valid on 'valid' subset:  58%|██▉  | 81/140 [00:07<00:04, 12.23it/s]
# epoch 002 | valid on 'valid' subset:  59%|██▉  | 83/140 [00:07<00:04, 11.50it/s]
# epoch 002 | valid on 'valid' subset:  61%|███  | 85/140 [00:08<00:04, 12.23it/s]
# epoch 002 | valid on 'valid' subset:  62%|███  | 87/140 [00:08<00:04, 11.71it/s]
# epoch 002 | valid on 'valid' subset:  64%|███▏ | 89/140 [00:08<00:04, 11.33it/s]
# epoch 002 | valid on 'valid' subset:  65%|███▎ | 91/140 [00:08<00:04, 11.00it/s]
# epoch 002 | valid on 'valid' subset:  66%|███▎ | 93/140 [00:08<00:03, 11.97it/s]
# epoch 002 | valid on 'valid' subset:  68%|███▍ | 95/140 [00:08<00:03, 11.68it/s]
# epoch 002 | valid on 'valid' subset:  69%|███▍ | 97/140 [00:09<00:03, 11.42it/s]
# epoch 002 | valid on 'valid' subset:  71%|███▌ | 99/140 [00:09<00:03, 12.50it/s]
# epoch 002 | valid on 'valid' subset:  72%|██▉ | 101/140 [00:09<00:03, 11.91it/s]
# epoch 002 | valid on 'valid' subset:  74%|██▉ | 103/140 [00:09<00:03, 11.46it/s]
# epoch 002 | valid on 'valid' subset:  75%|███ | 105/140 [00:09<00:02, 12.40it/s]
# epoch 002 | valid on 'valid' subset:  76%|███ | 107/140 [00:09<00:02, 11.97it/s]
# epoch 002 | valid on 'valid' subset:  78%|███ | 109/140 [00:10<00:02, 11.68it/s]
# epoch 002 | valid on 'valid' subset:  79%|███▏| 111/140 [00:10<00:02, 12.90it/s]
# epoch 002 | valid on 'valid' subset:  81%|███▏| 113/140 [00:10<00:01, 13.70it/s]
# epoch 002 | valid on 'valid' subset:  82%|███▎| 115/140 [00:10<00:01, 12.94it/s]
# epoch 002 | valid on 'valid' subset:  84%|███▎| 117/140 [00:10<00:01, 14.15it/s]
# epoch 002 | valid on 'valid' subset:  85%|███▍| 119/140 [00:10<00:01, 13.30it/s]
# epoch 002 | valid on 'valid' subset:  86%|███▍| 121/140 [00:10<00:01, 14.27it/s]
# epoch 002 | valid on 'valid' subset:  88%|███▌| 123/140 [00:11<00:01, 14.86it/s]
# epoch 002 | valid on 'valid' subset:  89%|███▌| 125/140 [00:11<00:01, 13.77it/s]
# epoch 002 | valid on 'valid' subset:  91%|███▋| 127/140 [00:11<00:00, 14.52it/s]
# epoch 002 | valid on 'valid' subset:  92%|███▋| 129/140 [00:11<00:00, 15.29it/s]
# epoch 002 | valid on 'valid' subset:  94%|███▋| 131/140 [00:11<00:00, 13.98it/s]
# epoch 002 | valid on 'valid' subset:  95%|███▊| 133/140 [00:11<00:00, 14.71it/s]
# epoch 002 | valid on 'valid' subset:  96%|███▊| 135/140 [00:11<00:00, 15.80it/s]
# epoch 002 | valid on 'valid' subset:  98%|███▉| 137/140 [00:12<00:00, 14.52it/s]
# epoch 002 | valid on 'valid' subset:  99%|███▉| 139/140 [00:12<00:00, 15.21it/s]
#                                                                                 2022-01-02 18:20:07 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 0.298 | ppl 1.23 | wps 6535.3 | wpb 557.1 | bsz 154.9 | num_updates 2160 | best_loss 0.298
# 2022-01-02 18:20:07 | INFO | fairseq_cli.train | begin save checkpoint
# 2022-01-02 18:20:08 | INFO | fairseq.checkpoint_utils | saved checkpoint data/mt-ckpt/checkpoint2.pt (epoch 2 @ 2160 updates, score 0.298) (writing took 1.493511094711721 seconds)
# 2022-01-02 18:20:08 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2022-01-02 18:20:08 | INFO | train | epoch 002 | loss 0.33 | ppl 1.26 | wps 1350.4 | ups 2.4 | wpb 561.6 | bsz 156.2 | num_updates 2160 | lr 0.001 | gnorm 0.444 | train_wall 428 | wall 885
# epoch 003:   0%|                                       | 0/1080 [00:00<?, ?it/s]2022-01-02 18:20:08 | INFO | fairseq.trainer | begin training epoch 3
# epoch 003: 100%|▉| 1079/1080 [07:17<00:00,  2.34it/s, loss=0.215, ppl=1.16, wps=2022-01-02 18:27:26 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 003 | valid on 'valid' subset:   0%|              | 0/140 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:   1%|      | 1/140 [00:00<01:22,  1.69it/s]
# epoch 003 | valid on 'valid' subset:   1%|      | 2/140 [00:00<00:49,  2.77it/s]
# epoch 003 | valid on 'valid' subset:   2%|▏     | 3/140 [00:00<00:34,  3.93it/s]
# epoch 003 | valid on 'valid' subset:   3%|▏     | 4/140 [00:01<00:30,  4.41it/s]
# epoch 003 | valid on 'valid' subset:   4%|▏     | 5/140 [00:01<00:25,  5.37it/s]
# epoch 003 | valid on 'valid' subset:   4%|▎     | 6/140 [00:01<00:21,  6.16it/s]
# epoch 003 | valid on 'valid' subset:   5%|▎     | 7/140 [00:01<00:21,  6.16it/s]
# epoch 003 | valid on 'valid' subset:   6%|▎     | 8/140 [00:01<00:19,  6.89it/s]
# epoch 003 | valid on 'valid' subset:   6%|▍     | 9/140 [00:01<00:17,  7.49it/s]
# epoch 003 | valid on 'valid' subset:   7%|▎    | 10/140 [00:01<00:16,  8.05it/s]
# epoch 003 | valid on 'valid' subset:   8%|▍    | 11/140 [00:01<00:15,  8.41it/s]
# epoch 003 | valid on 'valid' subset:   9%|▍    | 13/140 [00:02<00:13,  9.37it/s]
# epoch 003 | valid on 'valid' subset:  11%|▌    | 15/140 [00:02<00:12,  9.74it/s]
# epoch 003 | valid on 'valid' subset:  12%|▌    | 17/140 [00:02<00:10, 11.30it/s]
# epoch 003 | valid on 'valid' subset:  14%|▋    | 19/140 [00:02<00:10, 11.12it/s]
# epoch 003 | valid on 'valid' subset:  15%|▊    | 21/140 [00:02<00:10, 10.89it/s]
# epoch 003 | valid on 'valid' subset:  16%|▊    | 23/140 [00:02<00:10, 10.88it/s]
# epoch 003 | valid on 'valid' subset:  18%|▉    | 25/140 [00:03<00:09, 11.98it/s]
# epoch 003 | valid on 'valid' subset:  19%|▉    | 27/140 [00:03<00:09, 11.68it/s]
# epoch 003 | valid on 'valid' subset:  21%|█    | 29/140 [00:03<00:08, 12.79it/s]
# epoch 003 | valid on 'valid' subset:  22%|█    | 31/140 [00:03<00:08, 12.30it/s]
# epoch 003 | valid on 'valid' subset:  24%|█▏   | 33/140 [00:03<00:07, 13.44it/s]
# epoch 003 | valid on 'valid' subset:  25%|█▎   | 35/140 [00:03<00:08, 12.79it/s]
# epoch 003 | valid on 'valid' subset:  26%|█▎   | 37/140 [00:04<00:07, 13.87it/s]
# epoch 003 | valid on 'valid' subset:  28%|█▍   | 39/140 [00:04<00:06, 14.84it/s]
# epoch 003 | valid on 'valid' subset:  29%|█▍   | 41/140 [00:04<00:07, 13.75it/s]
# epoch 003 | valid on 'valid' subset:  31%|█▌   | 43/140 [00:04<00:06, 14.57it/s]
# epoch 003 | valid on 'valid' subset:  32%|█▌   | 45/140 [00:04<00:06, 15.13it/s]
# epoch 003 | valid on 'valid' subset:  34%|█▋   | 47/140 [00:04<00:06, 13.73it/s]
# epoch 003 | valid on 'valid' subset:  35%|█▊   | 49/140 [00:04<00:06, 14.40it/s]
# epoch 003 | valid on 'valid' subset:  36%|█▊   | 51/140 [00:04<00:06, 13.51it/s]
# epoch 003 | valid on 'valid' subset:  38%|█▉   | 53/140 [00:05<00:06, 14.15it/s]
# epoch 003 | valid on 'valid' subset:  39%|█▉   | 55/140 [00:05<00:06, 12.99it/s]
# epoch 003 | valid on 'valid' subset:  41%|██   | 57/140 [00:05<00:06, 12.08it/s]
# epoch 003 | valid on 'valid' subset:  42%|██   | 59/140 [00:05<00:06, 12.87it/s]
# epoch 003 | valid on 'valid' subset:  44%|██▏  | 61/140 [00:05<00:06, 11.93it/s]
# epoch 003 | valid on 'valid' subset:  45%|██▎  | 63/140 [00:06<00:06, 11.43it/s]
# epoch 003 | valid on 'valid' subset:  46%|██▎  | 65/140 [00:06<00:06, 11.15it/s]
# epoch 003 | valid on 'valid' subset:  48%|██▍  | 67/140 [00:06<00:05, 12.36it/s]
# epoch 003 | valid on 'valid' subset:  49%|██▍  | 69/140 [00:06<00:05, 12.02it/s]
# epoch 003 | valid on 'valid' subset:  51%|██▌  | 71/140 [00:06<00:05, 13.15it/s]
# epoch 003 | valid on 'valid' subset:  52%|██▌  | 73/140 [00:06<00:05, 12.74it/s]
# epoch 003 | valid on 'valid' subset:  54%|██▋  | 75/140 [00:06<00:04, 13.81it/s]
# epoch 003 | valid on 'valid' subset:  55%|██▊  | 77/140 [00:07<00:04, 12.92it/s]
# epoch 003 | valid on 'valid' subset:  56%|██▊  | 79/140 [00:07<00:04, 13.98it/s]
# epoch 003 | valid on 'valid' subset:  58%|██▉  | 81/140 [00:07<00:04, 14.36it/s]
# epoch 003 | valid on 'valid' subset:  59%|██▉  | 83/140 [00:07<00:04, 13.14it/s]
# epoch 003 | valid on 'valid' subset:  61%|███  | 85/140 [00:07<00:04, 12.61it/s]
# epoch 003 | valid on 'valid' subset:  62%|███  | 87/140 [00:07<00:03, 13.68it/s]
# epoch 003 | valid on 'valid' subset:  64%|███▏ | 89/140 [00:07<00:03, 14.60it/s]
# epoch 003 | valid on 'valid' subset:  65%|███▎ | 91/140 [00:08<00:03, 13.43it/s]
# epoch 003 | valid on 'valid' subset:  66%|███▎ | 93/140 [00:08<00:03, 14.40it/s]
# epoch 003 | valid on 'valid' subset:  68%|███▍ | 95/140 [00:08<00:02, 15.06it/s]
# epoch 003 | valid on 'valid' subset:  69%|███▍ | 97/140 [00:08<00:03, 13.89it/s]
# epoch 003 | valid on 'valid' subset:  71%|███▌ | 99/140 [00:08<00:02, 14.81it/s]
# epoch 003 | valid on 'valid' subset:  72%|██▉ | 101/140 [00:08<00:02, 13.59it/s]
# epoch 003 | valid on 'valid' subset:  74%|██▉ | 103/140 [00:08<00:02, 14.39it/s]
# epoch 003 | valid on 'valid' subset:  75%|███ | 105/140 [00:09<00:02, 15.15it/s]
# epoch 003 | valid on 'valid' subset:  76%|███ | 107/140 [00:09<00:02, 13.76it/s]
# epoch 003 | valid on 'valid' subset:  78%|███ | 109/140 [00:09<00:02, 14.55it/s]
# epoch 003 | valid on 'valid' subset:  79%|███▏| 111/140 [00:09<00:02, 13.10it/s]
# epoch 003 | valid on 'valid' subset:  81%|███▏| 113/140 [00:09<00:01, 14.10it/s]
# epoch 003 | valid on 'valid' subset:  82%|███▎| 115/140 [00:09<00:01, 13.20it/s]
# epoch 003 | valid on 'valid' subset:  84%|███▎| 117/140 [00:09<00:01, 14.12it/s]
# epoch 003 | valid on 'valid' subset:  85%|███▍| 119/140 [00:10<00:01, 13.07it/s]
# epoch 003 | valid on 'valid' subset:  86%|███▍| 121/140 [00:10<00:01, 14.26it/s]
# epoch 003 | valid on 'valid' subset:  88%|███▌| 123/140 [00:10<00:01, 12.80it/s]
# epoch 003 | valid on 'valid' subset:  89%|███▌| 125/140 [00:10<00:01, 12.15it/s]
# epoch 003 | valid on 'valid' subset:  91%|███▋| 127/140 [00:10<00:00, 13.10it/s]
# epoch 003 | valid on 'valid' subset:  92%|███▋| 129/140 [00:10<00:00, 12.42it/s]
# epoch 003 | valid on 'valid' subset:  94%|███▋| 131/140 [00:11<00:00, 13.04it/s]
# epoch 003 | valid on 'valid' subset:  95%|███▊| 133/140 [00:11<00:00, 12.26it/s]
# epoch 003 | valid on 'valid' subset:  96%|███▊| 135/140 [00:11<00:00, 12.00it/s]
# epoch 003 | valid on 'valid' subset:  98%|███▉| 137/140 [00:11<00:00, 13.37it/s]
# epoch 003 | valid on 'valid' subset:  99%|███▉| 139/140 [00:11<00:00, 14.49it/s]
#                                                                                 2022-01-02 18:27:38 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 0.261 | ppl 1.2 | wps 6874.5 | wpb 557.1 | bsz 154.9 | num_updates 3240 | best_loss 0.261
# 2022-01-02 18:27:38 | INFO | fairseq_cli.train | begin save checkpoint
# 2022-01-02 18:27:39 | INFO | fairseq.checkpoint_utils | saved checkpoint data/mt-ckpt/checkpoint3.pt (epoch 3 @ 3240 updates, score 0.261) (writing took 1.5258296518586576 seconds)
# 2022-01-02 18:27:39 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2022-01-02 18:27:39 | INFO | train | epoch 003 | loss 0.247 | ppl 1.19 | wps 1345.3 | ups 2.4 | wpb 561.6 | bsz 156.2 | num_updates 3240 | lr 0.001 | gnorm 0.353 | train_wall 430 | wall 1336
# epoch 004:   0%|                                       | 0/1080 [00:00<?, ?it/s]2022-01-02 18:27:39 | INFO | fairseq.trainer | begin training epoch 4
# epoch 004: 100%|▉| 1079/1080 [07:14<00:00,  2.42it/s, loss=0.226, ppl=1.17, wps=2022-01-02 18:34:55 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 004 | valid on 'valid' subset:   0%|              | 0/140 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:   1%|      | 1/140 [00:00<01:17,  1.80it/s]
# epoch 004 | valid on 'valid' subset:   1%|      | 2/140 [00:00<00:48,  2.85it/s]
# epoch 004 | valid on 'valid' subset:   2%|▏     | 3/140 [00:00<00:37,  3.61it/s]
# epoch 004 | valid on 'valid' subset:   3%|▏     | 4/140 [00:01<00:33,  4.12it/s]
# epoch 004 | valid on 'valid' subset:   4%|▏     | 5/140 [00:01<00:27,  4.97it/s]
# epoch 004 | valid on 'valid' subset:   4%|▎     | 6/140 [00:01<00:22,  5.85it/s]
# epoch 004 | valid on 'valid' subset:   5%|▎     | 7/140 [00:01<00:22,  5.87it/s]
# epoch 004 | valid on 'valid' subset:   6%|▎     | 8/140 [00:01<00:20,  6.59it/s]
# epoch 004 | valid on 'valid' subset:   6%|▍     | 9/140 [00:01<00:18,  7.13it/s]
# epoch 004 | valid on 'valid' subset:   7%|▎    | 10/140 [00:01<00:19,  6.82it/s]
# epoch 004 | valid on 'valid' subset:   8%|▍    | 11/140 [00:02<00:17,  7.37it/s]
# epoch 004 | valid on 'valid' subset:   9%|▍    | 12/140 [00:02<00:16,  7.90it/s]
# epoch 004 | valid on 'valid' subset:   9%|▍    | 13/140 [00:02<00:15,  8.24it/s]
# epoch 004 | valid on 'valid' subset:  10%|▌    | 14/140 [00:02<00:14,  8.68it/s]
# epoch 004 | valid on 'valid' subset:  11%|▌    | 15/140 [00:02<00:14,  8.92it/s]
# epoch 004 | valid on 'valid' subset:  12%|▌    | 17/140 [00:02<00:13,  9.30it/s]
# epoch 004 | valid on 'valid' subset:  14%|▋    | 19/140 [00:02<00:12,  9.82it/s]
# epoch 004 | valid on 'valid' subset:  15%|▊    | 21/140 [00:03<00:11, 10.21it/s]
# epoch 004 | valid on 'valid' subset:  16%|▊    | 23/140 [00:03<00:09, 11.72it/s]
# epoch 004 | valid on 'valid' subset:  18%|▉    | 25/140 [00:03<00:10, 11.48it/s]
# epoch 004 | valid on 'valid' subset:  19%|▉    | 27/140 [00:03<00:08, 12.66it/s]
# epoch 004 | valid on 'valid' subset:  21%|█    | 29/140 [00:03<00:09, 12.03it/s]
# epoch 004 | valid on 'valid' subset:  22%|█    | 31/140 [00:03<00:08, 13.14it/s]
# epoch 004 | valid on 'valid' subset:  24%|█▏   | 33/140 [00:03<00:08, 12.48it/s]
# epoch 004 | valid on 'valid' subset:  25%|█▎   | 35/140 [00:04<00:07, 13.58it/s]
# epoch 004 | valid on 'valid' subset:  26%|█▎   | 37/140 [00:04<00:07, 12.92it/s]
# epoch 004 | valid on 'valid' subset:  28%|█▍   | 39/140 [00:04<00:07, 14.05it/s]
# epoch 004 | valid on 'valid' subset:  29%|█▍   | 41/140 [00:04<00:06, 14.93it/s]
# epoch 004 | valid on 'valid' subset:  31%|█▌   | 43/140 [00:04<00:07, 13.67it/s]
# epoch 004 | valid on 'valid' subset:  32%|█▌   | 45/140 [00:04<00:06, 14.51it/s]
# epoch 004 | valid on 'valid' subset:  34%|█▋   | 47/140 [00:04<00:06, 13.44it/s]
# epoch 004 | valid on 'valid' subset:  35%|█▊   | 49/140 [00:05<00:06, 14.20it/s]
# epoch 004 | valid on 'valid' subset:  36%|█▊   | 51/140 [00:05<00:05, 15.08it/s]
# epoch 004 | valid on 'valid' subset:  38%|█▉   | 53/140 [00:05<00:06, 13.64it/s]
# epoch 004 | valid on 'valid' subset:  39%|█▉   | 55/140 [00:05<00:05, 14.47it/s]
# epoch 004 | valid on 'valid' subset:  41%|██   | 57/140 [00:05<00:06, 12.79it/s]
# epoch 004 | valid on 'valid' subset:  42%|██   | 59/140 [00:05<00:06, 11.97it/s]
# epoch 004 | valid on 'valid' subset:  44%|██▏  | 61/140 [00:06<00:06, 11.43it/s]
# epoch 004 | valid on 'valid' subset:  45%|██▎  | 63/140 [00:06<00:06, 11.15it/s]
# epoch 004 | valid on 'valid' subset:  46%|██▎  | 65/140 [00:06<00:06, 10.79it/s]
# epoch 004 | valid on 'valid' subset:  48%|██▍  | 67/140 [00:06<00:06, 10.72it/s]
# epoch 004 | valid on 'valid' subset:  49%|██▍  | 69/140 [00:06<00:06, 11.51it/s]
# epoch 004 | valid on 'valid' subset:  51%|██▌  | 71/140 [00:06<00:06, 11.29it/s]
# epoch 004 | valid on 'valid' subset:  52%|██▌  | 73/140 [00:07<00:05, 11.40it/s]
# epoch 004 | valid on 'valid' subset:  54%|██▋  | 75/140 [00:07<00:05, 12.53it/s]
# epoch 004 | valid on 'valid' subset:  55%|██▊  | 77/140 [00:07<00:05, 11.99it/s]
# epoch 004 | valid on 'valid' subset:  56%|██▊  | 79/140 [00:07<00:04, 13.14it/s]
# epoch 004 | valid on 'valid' subset:  58%|██▉  | 81/140 [00:07<00:04, 12.45it/s]
# epoch 004 | valid on 'valid' subset:  59%|██▉  | 83/140 [00:07<00:04, 13.49it/s]
# epoch 004 | valid on 'valid' subset:  61%|███  | 85/140 [00:08<00:04, 12.79it/s]
# epoch 004 | valid on 'valid' subset:  62%|███  | 87/140 [00:08<00:03, 13.92it/s]
# epoch 004 | valid on 'valid' subset:  64%|███▏ | 89/140 [00:08<00:03, 14.72it/s]
# epoch 004 | valid on 'valid' subset:  65%|███▎ | 91/140 [00:08<00:03, 13.26it/s]
# epoch 004 | valid on 'valid' subset:  66%|███▎ | 93/140 [00:08<00:03, 12.48it/s]
# epoch 004 | valid on 'valid' subset:  68%|███▍ | 95/140 [00:08<00:03, 13.55it/s]
# epoch 004 | valid on 'valid' subset:  69%|███▍ | 97/140 [00:08<00:02, 14.40it/s]
# epoch 004 | valid on 'valid' subset:  71%|███▌ | 99/140 [00:09<00:03, 13.42it/s]
# epoch 004 | valid on 'valid' subset:  72%|██▉ | 101/140 [00:09<00:02, 14.33it/s]
# epoch 004 | valid on 'valid' subset:  74%|██▉ | 103/140 [00:09<00:02, 13.22it/s]
# epoch 004 | valid on 'valid' subset:  75%|███ | 105/140 [00:09<00:02, 14.22it/s]
# epoch 004 | valid on 'valid' subset:  76%|███ | 107/140 [00:09<00:02, 12.82it/s]
# epoch 004 | valid on 'valid' subset:  78%|███ | 109/140 [00:09<00:02, 12.00it/s]
# epoch 004 | valid on 'valid' subset:  79%|███▏| 111/140 [00:09<00:02, 12.68it/s]
# epoch 004 | valid on 'valid' subset:  81%|███▏| 113/140 [00:10<00:02, 11.83it/s]
# epoch 004 | valid on 'valid' subset:  82%|███▎| 115/140 [00:10<00:02, 11.40it/s]
# epoch 004 | valid on 'valid' subset:  84%|███▎| 117/140 [00:10<00:02, 11.15it/s]
# epoch 004 | valid on 'valid' subset:  85%|███▍| 119/140 [00:10<00:01, 11.01it/s]
# epoch 004 | valid on 'valid' subset:  86%|███▍| 121/140 [00:10<00:01, 11.89it/s]
# epoch 004 | valid on 'valid' subset:  88%|███▌| 123/140 [00:11<00:01, 11.59it/s]
# epoch 004 | valid on 'valid' subset:  89%|███▌| 125/140 [00:11<00:01, 11.20it/s]
# epoch 004 | valid on 'valid' subset:  91%|███▋| 127/140 [00:11<00:01, 11.09it/s]
# epoch 004 | valid on 'valid' subset:  92%|███▋| 129/140 [00:11<00:00, 11.89it/s]
# epoch 004 | valid on 'valid' subset:  94%|███▋| 131/140 [00:11<00:00, 11.40it/s]
# epoch 004 | valid on 'valid' subset:  95%|███▊| 133/140 [00:11<00:00, 11.22it/s]
# epoch 004 | valid on 'valid' subset:  96%|███▊| 135/140 [00:12<00:00, 12.81it/s]
# epoch 004 | valid on 'valid' subset:  98%|███▉| 137/140 [00:12<00:00, 13.93it/s]
# epoch 004 | valid on 'valid' subset:  99%|███▉| 139/140 [00:12<00:00, 13.30it/s]
#                                                                                 2022-01-02 18:35:07 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 0.256 | ppl 1.19 | wps 6431.5 | wpb 557.1 | bsz 154.9 | num_updates 4320 | best_loss 0.256
# 2022-01-02 18:35:07 | INFO | fairseq_cli.train | begin save checkpoint
# 2022-01-02 18:35:08 | INFO | fairseq.checkpoint_utils | saved checkpoint data/mt-ckpt/checkpoint4.pt (epoch 4 @ 4320 updates, score 0.256) (writing took 1.4766528471373022 seconds)
# 2022-01-02 18:35:08 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2022-01-02 18:35:08 | INFO | train | epoch 004 | loss 0.207 | ppl 1.15 | wps 1349.8 | ups 2.4 | wpb 561.6 | bsz 156.2 | num_updates 4320 | lr 0.001 | gnorm 0.296 | train_wall 427 | wall 1786
# epoch 005:   0%|                                       | 0/1080 [00:00<?, ?it/s]2022-01-02 18:35:09 | INFO | fairseq.trainer | begin training epoch 5
# epoch 005: 100%|▉| 1079/1080 [07:14<00:00,  2.53it/s, loss=0.198, ppl=1.15, wps=2022-01-02 18:42:23 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 005 | valid on 'valid' subset:   0%|              | 0/140 [00:00<?, ?it/s]
# epoch 005 | valid on 'valid' subset:   1%|      | 1/140 [00:00<01:11,  1.95it/s]
# epoch 005 | valid on 'valid' subset:   1%|      | 2/140 [00:00<00:46,  2.98it/s]
# epoch 005 | valid on 'valid' subset:   2%|▏     | 3/140 [00:00<00:36,  3.71it/s]
# epoch 005 | valid on 'valid' subset:   3%|▏     | 4/140 [00:01<00:28,  4.76it/s]
# epoch 005 | valid on 'valid' subset:   4%|▏     | 5/140 [00:01<00:26,  5.02it/s]
# epoch 005 | valid on 'valid' subset:   4%|▎     | 6/140 [00:01<00:22,  5.88it/s]
# epoch 005 | valid on 'valid' subset:   5%|▎     | 7/140 [00:01<00:20,  6.61it/s]
# epoch 005 | valid on 'valid' subset:   6%|▎     | 8/140 [00:01<00:20,  6.42it/s]
# epoch 005 | valid on 'valid' subset:   6%|▍     | 9/140 [00:01<00:18,  7.06it/s]
# epoch 005 | valid on 'valid' subset:   8%|▍    | 11/140 [00:01<00:16,  7.97it/s]
# epoch 005 | valid on 'valid' subset:   9%|▍    | 13/140 [00:02<00:14,  8.64it/s]
# epoch 005 | valid on 'valid' subset:  11%|▌    | 15/140 [00:02<00:13,  9.06it/s]
# epoch 005 | valid on 'valid' subset:  12%|▌    | 17/140 [00:02<00:13,  9.35it/s]
# epoch 005 | valid on 'valid' subset:  14%|▋    | 19/140 [00:02<00:12,  9.62it/s]
# epoch 005 | valid on 'valid' subset:  14%|▋    | 20/140 [00:02<00:12,  9.68it/s]
# epoch 005 | valid on 'valid' subset:  16%|▊    | 22/140 [00:03<00:11, 10.13it/s]
# epoch 005 | valid on 'valid' subset:  17%|▊    | 24/140 [00:03<00:11, 10.33it/s]
# epoch 005 | valid on 'valid' subset:  19%|▉    | 26/140 [00:03<00:09, 11.70it/s]
# epoch 005 | valid on 'valid' subset:  20%|█    | 28/140 [00:03<00:09, 11.54it/s]
# epoch 005 | valid on 'valid' subset:  21%|█    | 30/140 [00:03<00:08, 12.72it/s]
# epoch 005 | valid on 'valid' subset:  23%|█▏   | 32/140 [00:03<00:08, 12.24it/s]
# epoch 005 | valid on 'valid' subset:  24%|█▏   | 34/140 [00:03<00:07, 13.28it/s]
# epoch 005 | valid on 'valid' subset:  26%|█▎   | 36/140 [00:04<00:07, 14.18it/s]
# epoch 005 | valid on 'valid' subset:  27%|█▎   | 38/140 [00:04<00:07, 13.29it/s]
# epoch 005 | valid on 'valid' subset:  29%|█▍   | 40/140 [00:04<00:07, 14.06it/s]
# epoch 005 | valid on 'valid' subset:  30%|█▌   | 42/140 [00:04<00:07, 13.26it/s]
# epoch 005 | valid on 'valid' subset:  31%|█▌   | 44/140 [00:04<00:06, 14.18it/s]
# epoch 005 | valid on 'valid' subset:  33%|█▋   | 46/140 [00:04<00:07, 13.08it/s]
# epoch 005 | valid on 'valid' subset:  34%|█▋   | 48/140 [00:04<00:06, 14.10it/s]
# epoch 005 | valid on 'valid' subset:  36%|█▊   | 50/140 [00:05<00:06, 13.01it/s]
# epoch 005 | valid on 'valid' subset:  37%|█▊   | 52/140 [00:05<00:06, 13.88it/s]
# epoch 005 | valid on 'valid' subset:  39%|█▉   | 54/140 [00:05<00:06, 12.97it/s]
# epoch 005 | valid on 'valid' subset:  40%|██   | 56/140 [00:05<00:07, 11.89it/s]
# epoch 005 | valid on 'valid' subset:  41%|██   | 58/140 [00:05<00:06, 13.03it/s]
# epoch 005 | valid on 'valid' subset:  43%|██▏  | 60/140 [00:05<00:06, 11.95it/s]
# epoch 005 | valid on 'valid' subset:  44%|██▏  | 62/140 [00:06<00:06, 11.41it/s]
# epoch 005 | valid on 'valid' subset:  46%|██▎  | 64/140 [00:06<00:06, 11.01it/s]
# epoch 005 | valid on 'valid' subset:  47%|██▎  | 66/140 [00:06<00:06, 10.80it/s]
# epoch 005 | valid on 'valid' subset:  49%|██▍  | 68/140 [00:06<00:06, 10.69it/s]
# epoch 005 | valid on 'valid' subset:  50%|██▌  | 70/140 [00:06<00:06, 10.44it/s]
# epoch 005 | valid on 'valid' subset:  51%|██▌  | 72/140 [00:07<00:05, 11.54it/s]
# epoch 005 | valid on 'valid' subset:  53%|██▋  | 74/140 [00:07<00:05, 11.17it/s]
# epoch 005 | valid on 'valid' subset:  54%|██▋  | 76/140 [00:07<00:05, 10.85it/s]
# epoch 005 | valid on 'valid' subset:  56%|██▊  | 78/140 [00:07<00:05, 10.67it/s]
# epoch 005 | valid on 'valid' subset:  57%|██▊  | 80/140 [00:07<00:05, 10.62it/s]
# epoch 005 | valid on 'valid' subset:  59%|██▉  | 82/140 [00:07<00:05, 10.54it/s]
# epoch 005 | valid on 'valid' subset:  60%|███  | 84/140 [00:08<00:04, 11.43it/s]
# epoch 005 | valid on 'valid' subset:  61%|███  | 86/140 [00:08<00:04, 11.19it/s]
# epoch 005 | valid on 'valid' subset:  63%|███▏ | 88/140 [00:08<00:04, 10.95it/s]
# epoch 005 | valid on 'valid' subset:  64%|███▏ | 90/140 [00:08<00:04, 10.81it/s]
# epoch 005 | valid on 'valid' subset:  66%|███▎ | 92/140 [00:08<00:04, 10.56it/s]
# epoch 005 | valid on 'valid' subset:  67%|███▎ | 94/140 [00:09<00:03, 11.55it/s]
# epoch 005 | valid on 'valid' subset:  69%|███▍ | 96/140 [00:09<00:03, 11.25it/s]
# epoch 005 | valid on 'valid' subset:  70%|███▌ | 98/140 [00:09<00:03, 11.00it/s]
# epoch 005 | valid on 'valid' subset:  71%|██▊ | 100/140 [00:09<00:03, 10.94it/s]
# epoch 005 | valid on 'valid' subset:  73%|██▉ | 102/140 [00:09<00:03, 10.74it/s]
# epoch 005 | valid on 'valid' subset:  74%|██▉ | 104/140 [00:09<00:03, 11.69it/s]
# epoch 005 | valid on 'valid' subset:  76%|███ | 106/140 [00:10<00:02, 11.40it/s]
# epoch 005 | valid on 'valid' subset:  77%|███ | 108/140 [00:10<00:02, 11.28it/s]
# epoch 005 | valid on 'valid' subset:  79%|███▏| 110/140 [00:10<00:02, 12.54it/s]
# epoch 005 | valid on 'valid' subset:  80%|███▏| 112/140 [00:10<00:02, 12.03it/s]
# epoch 005 | valid on 'valid' subset:  81%|███▎| 114/140 [00:10<00:02, 12.71it/s]
# epoch 005 | valid on 'valid' subset:  83%|███▎| 116/140 [00:10<00:01, 12.16it/s]
# epoch 005 | valid on 'valid' subset:  84%|███▎| 118/140 [00:11<00:01, 11.72it/s]
# epoch 005 | valid on 'valid' subset:  86%|███▍| 120/140 [00:11<00:01, 12.55it/s]
# epoch 005 | valid on 'valid' subset:  87%|███▍| 122/140 [00:11<00:01, 11.80it/s]
# epoch 005 | valid on 'valid' subset:  89%|███▌| 124/140 [00:11<00:01, 11.26it/s]
# epoch 005 | valid on 'valid' subset:  90%|███▌| 126/140 [00:11<00:01, 11.10it/s]
# epoch 005 | valid on 'valid' subset:  91%|███▋| 128/140 [00:12<00:01, 10.91it/s]
# epoch 005 | valid on 'valid' subset:  93%|███▋| 130/140 [00:12<00:00, 10.66it/s]
# epoch 005 | valid on 'valid' subset:  94%|███▊| 132/140 [00:12<00:00, 10.57it/s]
# epoch 005 | valid on 'valid' subset:  96%|███▊| 134/140 [00:12<00:00, 11.63it/s]
# epoch 005 | valid on 'valid' subset:  97%|███▉| 136/140 [00:12<00:00, 11.28it/s]
# epoch 005 | valid on 'valid' subset:  99%|███▉| 138/140 [00:12<00:00, 10.92it/s]
# epoch 005 | valid on 'valid' subset: 100%|████| 140/140 [00:13<00:00, 12.17it/s]
#                                                                                 2022-01-02 18:42:36 | INFO | valid | epoch 005 | valid on 'valid' subset | loss 0.239 | ppl 1.18 | wps 6059.8 | wpb 557.1 | bsz 154.9 | num_updates 5400 | best_loss 0.239
# 2022-01-02 18:42:36 | INFO | fairseq_cli.train | begin save checkpoint
# 2022-01-02 18:42:38 | INFO | fairseq.checkpoint_utils | saved checkpoint data/mt-ckpt/checkpoint5.pt (epoch 5 @ 5400 updates, score 0.239) (writing took 1.512207010295242 seconds)
# 2022-01-02 18:42:38 | INFO | fairseq_cli.train | end of epoch 5 (average epoch stats below)
# 2022-01-02 18:42:38 | INFO | train | epoch 005 | loss 0.184 | ppl 1.14 | wps 1350.1 | ups 2.4 | wpb 561.6 | bsz 156.2 | num_updates 5400 | lr 0.001 | gnorm 0.272 | train_wall 427 | wall 2235
# epoch 006:   0%|                                       | 0/1080 [00:00<?, ?it/s]2022-01-02 18:42:38 | INFO | fairseq.trainer | begin training epoch 6
# epoch 006: 100%|▉| 1079/1080 [07:16<00:00,  2.36it/s, loss=0.172, ppl=1.13, wps=2022-01-02 18:49:55 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 006 | valid on 'valid' subset:   0%|              | 0/140 [00:00<?, ?it/s]
# epoch 006 | valid on 'valid' subset:   1%|      | 1/140 [00:00<01:16,  1.81it/s]
# epoch 006 | valid on 'valid' subset:   1%|      | 2/140 [00:00<00:49,  2.82it/s]
# epoch 006 | valid on 'valid' subset:   2%|▏     | 3/140 [00:00<00:39,  3.49it/s]
# epoch 006 | valid on 'valid' subset:   3%|▏     | 4/140 [00:01<00:33,  4.04it/s]
# epoch 006 | valid on 'valid' subset:   4%|▏     | 5/140 [00:01<00:30,  4.43it/s]
# epoch 006 | valid on 'valid' subset:   4%|▎     | 6/140 [00:01<00:24,  5.37it/s]
# epoch 006 | valid on 'valid' subset:   5%|▎     | 7/140 [00:01<00:21,  6.19it/s]
# epoch 006 | valid on 'valid' subset:   6%|▎     | 8/140 [00:01<00:19,  6.81it/s]
# epoch 006 | valid on 'valid' subset:   6%|▍     | 9/140 [00:01<00:17,  7.52it/s]
# epoch 006 | valid on 'valid' subset:   7%|▎    | 10/140 [00:01<00:15,  8.14it/s]
# epoch 006 | valid on 'valid' subset:   8%|▍    | 11/140 [00:01<00:15,  8.54it/s]
# epoch 006 | valid on 'valid' subset:   9%|▍    | 13/140 [00:02<00:13,  9.36it/s]
# epoch 006 | valid on 'valid' subset:  11%|▌    | 15/140 [00:02<00:12,  9.96it/s]
# epoch 006 | valid on 'valid' subset:  12%|▌    | 17/140 [00:02<00:12, 10.17it/s]
# epoch 006 | valid on 'valid' subset:  14%|▋    | 19/140 [00:02<00:10, 11.52it/s]
# epoch 006 | valid on 'valid' subset:  15%|▊    | 21/140 [00:02<00:10, 11.20it/s]
# epoch 006 | valid on 'valid' subset:  16%|▊    | 23/140 [00:03<00:10, 11.21it/s]
# epoch 006 | valid on 'valid' subset:  18%|▉    | 25/140 [00:03<00:09, 12.49it/s]
# epoch 006 | valid on 'valid' subset:  19%|▉    | 27/140 [00:03<00:09, 12.11it/s]
# epoch 006 | valid on 'valid' subset:  21%|█    | 29/140 [00:03<00:08, 13.08it/s]
# epoch 006 | valid on 'valid' subset:  22%|█    | 31/140 [00:03<00:09, 11.99it/s]
# epoch 006 | valid on 'valid' subset:  24%|█▏   | 33/140 [00:03<00:09, 11.40it/s]
# epoch 006 | valid on 'valid' subset:  25%|█▎   | 35/140 [00:04<00:09, 11.05it/s]
# epoch 006 | valid on 'valid' subset:  26%|█▎   | 37/140 [00:04<00:09, 10.84it/s]
# epoch 006 | valid on 'valid' subset:  28%|█▍   | 39/140 [00:04<00:08, 11.90it/s]
# epoch 006 | valid on 'valid' subset:  29%|█▍   | 41/140 [00:04<00:08, 11.65it/s]
# epoch 006 | valid on 'valid' subset:  31%|█▌   | 43/140 [00:04<00:07, 12.86it/s]
# epoch 006 | valid on 'valid' subset:  32%|█▌   | 45/140 [00:04<00:07, 12.42it/s]
# epoch 006 | valid on 'valid' subset:  34%|█▋   | 47/140 [00:04<00:06, 13.58it/s]
# epoch 006 | valid on 'valid' subset:  35%|█▊   | 49/140 [00:05<00:06, 14.43it/s]
# epoch 006 | valid on 'valid' subset:  36%|█▊   | 51/140 [00:05<00:06, 13.56it/s]
# epoch 006 | valid on 'valid' subset:  38%|█▉   | 53/140 [00:05<00:06, 14.36it/s]
# epoch 006 | valid on 'valid' subset:  39%|█▉   | 55/140 [00:05<00:06, 13.26it/s]
# epoch 006 | valid on 'valid' subset:  41%|██   | 57/140 [00:05<00:05, 14.10it/s]
# epoch 006 | valid on 'valid' subset:  42%|██   | 59/140 [00:05<00:06, 13.12it/s]
# epoch 006 | valid on 'valid' subset:  44%|██▏  | 61/140 [00:05<00:05, 13.98it/s]
# epoch 006 | valid on 'valid' subset:  45%|██▎  | 63/140 [00:06<00:05, 14.91it/s]
# epoch 006 | valid on 'valid' subset:  46%|██▎  | 65/140 [00:06<00:05, 13.50it/s]
# epoch 006 | valid on 'valid' subset:  48%|██▍  | 67/140 [00:06<00:05, 14.52it/s]
# epoch 006 | valid on 'valid' subset:  49%|██▍  | 69/140 [00:06<00:05, 13.13it/s]
# epoch 006 | valid on 'valid' subset:  51%|██▌  | 71/140 [00:06<00:04, 13.99it/s]
# epoch 006 | valid on 'valid' subset:  52%|██▌  | 73/140 [00:06<00:05, 13.13it/s]
# epoch 006 | valid on 'valid' subset:  54%|██▋  | 75/140 [00:07<00:05, 12.31it/s]
# epoch 006 | valid on 'valid' subset:  55%|██▊  | 77/140 [00:07<00:05, 11.45it/s]
# epoch 006 | valid on 'valid' subset:  56%|██▊  | 79/140 [00:07<00:04, 12.30it/s]
# epoch 006 | valid on 'valid' subset:  58%|██▉  | 81/140 [00:07<00:05, 11.65it/s]
# epoch 006 | valid on 'valid' subset:  59%|██▉  | 83/140 [00:07<00:05, 11.11it/s]
# epoch 006 | valid on 'valid' subset:  61%|███  | 85/140 [00:07<00:04, 11.22it/s]
# epoch 006 | valid on 'valid' subset:  62%|███  | 87/140 [00:08<00:04, 12.58it/s]
# epoch 006 | valid on 'valid' subset:  64%|███▏ | 89/140 [00:08<00:03, 13.80it/s]
# epoch 006 | valid on 'valid' subset:  65%|███▎ | 91/140 [00:08<00:03, 13.00it/s]
# epoch 006 | valid on 'valid' subset:  66%|███▎ | 93/140 [00:08<00:03, 13.99it/s]
# epoch 006 | valid on 'valid' subset:  68%|███▍ | 95/140 [00:08<00:03, 14.86it/s]
# epoch 006 | valid on 'valid' subset:  69%|███▍ | 97/140 [00:08<00:03, 13.72it/s]
# epoch 006 | valid on 'valid' subset:  71%|███▌ | 99/140 [00:08<00:02, 14.73it/s]
# epoch 006 | valid on 'valid' subset:  72%|██▉ | 101/140 [00:08<00:02, 15.36it/s]
# epoch 006 | valid on 'valid' subset:  74%|██▉ | 103/140 [00:09<00:02, 13.75it/s]
# epoch 006 | valid on 'valid' subset:  75%|███ | 105/140 [00:09<00:02, 14.66it/s]
# epoch 006 | valid on 'valid' subset:  76%|███ | 107/140 [00:09<00:02, 13.63it/s]
# epoch 006 | valid on 'valid' subset:  78%|███ | 109/140 [00:09<00:02, 14.52it/s]
# epoch 006 | valid on 'valid' subset:  79%|███▏| 111/140 [00:09<00:01, 15.14it/s]
# epoch 006 | valid on 'valid' subset:  81%|███▏| 113/140 [00:09<00:01, 13.80it/s]
# epoch 006 | valid on 'valid' subset:  82%|███▎| 115/140 [00:09<00:01, 14.62it/s]
# epoch 006 | valid on 'valid' subset:  84%|███▎| 117/140 [00:10<00:01, 13.71it/s]
# epoch 006 | valid on 'valid' subset:  85%|███▍| 119/140 [00:10<00:01, 14.65it/s]
# epoch 006 | valid on 'valid' subset:  86%|███▍| 121/140 [00:10<00:01, 15.36it/s]
# epoch 006 | valid on 'valid' subset:  88%|███▌| 123/140 [00:10<00:01, 13.87it/s]
# epoch 006 | valid on 'valid' subset:  89%|███▌| 125/140 [00:10<00:01, 14.69it/s]
# epoch 006 | valid on 'valid' subset:  91%|███▋| 127/140 [00:10<00:00, 13.26it/s]
# epoch 006 | valid on 'valid' subset:  92%|███▋| 129/140 [00:11<00:00, 12.29it/s]
# epoch 006 | valid on 'valid' subset:  94%|███▋| 131/140 [00:11<00:00, 13.25it/s]
# epoch 006 | valid on 'valid' subset:  95%|███▊| 133/140 [00:11<00:00, 12.60it/s]
# epoch 006 | valid on 'valid' subset:  96%|███▊| 135/140 [00:11<00:00, 13.41it/s]
# epoch 006 | valid on 'valid' subset:  98%|███▉| 137/140 [00:11<00:00, 12.53it/s]
# epoch 006 | valid on 'valid' subset:  99%|███▉| 139/140 [00:11<00:00, 13.65it/s]
#                                                                                 2022-01-02 18:50:06 | INFO | valid | epoch 006 | valid on 'valid' subset | loss 0.244 | ppl 1.18 | wps 6752.7 | wpb 557.1 | bsz 154.9 | num_updates 6480 | best_loss 0.239
# 2022-01-02 18:50:06 | INFO | fairseq_cli.train | begin save checkpoint
# 2022-01-02 18:50:07 | INFO | fairseq.checkpoint_utils | saved checkpoint data/mt-ckpt/checkpoint6.pt (epoch 6 @ 6480 updates, score 0.244) (writing took 0.47411059821024537 seconds)
# 2022-01-02 18:50:07 | INFO | fairseq_cli.train | end of epoch 6 (average epoch stats below)
# 2022-01-02 18:50:07 | INFO | train | epoch 006 | loss 0.17 | ppl 1.13 | wps 1350.3 | ups 2.4 | wpb 561.6 | bsz 156.2 | num_updates 6480 | lr 0.001 | gnorm 0.253 | train_wall 428 | wall 2684
# epoch 007:   0%|                                       | 0/1080 [00:00<?, ?it/s]2022-01-02 18:50:07 | INFO | fairseq.trainer | begin training epoch 7
# epoch 007:  19%|▏| 200/1080 [01:21<05:57,  2.46it/s, loss=0.131, ppl=1.1, wps=13^C
# Traceback (most recent call last):
#   File "/home/default/bin/fairseq-train", line 8, in <module>
#     sys.exit(cli_main())
#   File "/home/default/lib/python3.8/site-packages/fairseq_cli/train.py", line 352, in cli_main
#     distributed_utils.call_main(args, main)
#   File "/home/default/lib/python3.8/site-packages/fairseq/distributed_utils.py", line 301, in call_main
#     main(args, **kwargs)
#   File "/home/default/lib/python3.8/site-packages/fairseq_cli/train.py", line 125, in main
#     valid_losses, should_stop = train(args, trainer, task, epoch_itr)
#   File "/usr/local/lib/python3.8/contextlib.py", line 75, in inner
#     return func(*args, **kwds)
#   File "/home/default/lib/python3.8/site-packages/fairseq_cli/train.py", line 208, in train
#     log_output = trainer.train_step(samples)
#   File "/usr/local/lib/python3.8/contextlib.py", line 75, in inner
#     return func(*args, **kwds)
#   File "/home/default/lib/python3.8/site-packages/fairseq/trainer.py", line 480, in train_step
#     loss, sample_size_i, logging_output = self.task.train_step(
#   File "/home/default/lib/python3.8/site-packages/fairseq/tasks/fairseq_task.py", line 420, in train_step
#     optimizer.backward(loss)
#   File "/home/default/lib/python3.8/site-packages/fairseq/optim/fairseq_optimizer.py", line 95, in backward
#     loss.backward()
#   File "/home/default/lib/python3.8/site-packages/torch/_tensor.py", line 307, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/home/default/lib/python3.8/site-packages/torch/autograd/__init__.py", line 154, in backward
#     Variable._execution_engine.run_backward(
# KeyboardInterrupt

# %%
# !fairseq-generate \
    data/mt-bin \
    --path data/mt-ckpt/checkpoint_best.pt \
    --tokenizer moses \
    --beam 3 \
    --results-path data/mt-test
# Out:
#   0%|                                                   | 0/111 [00:00<?, ?it/s]/home/default/lib/python3.8/site-packages/fairseq/search.py:140: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beams_buf = indices_buf // vocab_size
# /home/default/lib/python3.8/site-packages/fairseq/sequence_generator.py:651: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   unfin_idx = idx // beam_size

# %%
# !grep ^T data/mt-test/generate-test.txt | cut -f1- > name.txt

# %%
# !grep ^T data/mt-test/generate-test.txt | cut -f2- > target.txt

# %%
# !grep ^H data/mt-test/generate-test.txt | cut -f3- > hypotheses.txt

# %%
results = pd.read_csv("name.txt", sep="\t", header=None)

# %%
y_pred = pd.read_csv("hypotheses.txt",header=None)
y_pred = y_pred.rename(columns={0:"pred"})

# %%
results["index"] = results[0].str.strip("T-")
results = pd.concat((results,y_pred),axis=1)

# %%
test = pd.read_csv("data/mt/categorizer.cs_cat.test.tsv", nrows=80000, sep="\t",header=None)

# %%
test = test.rename(columns={0:"NAME",1:"CATEGORY_SEQ_STR"})

# %%
evaluation = test.copy()

# %%
[int(i) for i in new.CATEGORY_SEQ_STR.str.split().tolist()[0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-241-7af3135f0b6d> in <module>
# ----> 1 [int(i) for i in new.CATEGORY_SEQ_STR.str.split().tolist()[0]]
#
# TypeError: 'float' object is not iterable

# %%
new_df = pd.DataFrame()
for _,i in results.iterrows():
    index = int(i["index"])
    if index<80000:
        string_categories = i["pred"].strip("[]").split(" ")
        categories = [int(i) for i in string_categories if i!=""]
        encoded_categories = label_enc.inverse_transform(categories)

        new = evaluation.iloc[index:index+1].copy()
        new["results"] = " > ".join(encoded_categories[1:])
        try:
            true_categories = label_enc.inverse_transform(([int(i) for i in new.CATEGORY_SEQ_STR.str.split().tolist()[0]]))
        except:
            continue
        new["CATEGORY_TRUE"] = " > ".join(true_categories[1:])
        size = (true_categories.shape if encoded_categories.shape >= true_categories.shape else encoded_categories.shape)[0]
        new["same"] = (encoded_categories[:size] == true_categories[:size]).all()
        new_df = new_df.append(new)

# %%
new_df.to_csv("test_lstm.csv",index=False)

# %%
subset["CATEGORY_TRUE"] = subset.CATEGORY_SEQ.apply(label_enc.inverse_transform)

# %%
new_df["results_post"] = new_df.results.apply(lambda x: " > ".join(x))

# %%
new_cats = new_df["results_post"].unique()
old_cats = subset.CATEGORY_PATH.unique()

# %%
for i in new_cats:
    if i in old_cats:
        pass
    else:
        print(i)
        print(new_df[(new_df.results_post == i)][["NAME","CATEGORY_TRUE"]].values)
# Out:
# Hobby a zahrada > Nářadí elektrické > Zahradní houpačky, houpací sítě
# [['Diamond flexibilní brusný kotouč'
#   array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#         dtype='<U31')                                                        ]
#  ['Diamond flexibilní brusný kotouč'
#   array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#         dtype='<U31')                                                        ]]
# Hobby a zahrada > Kuchyně > Dřezy
# [['Zorba 440E - Sand'
#   array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Dřezy'], dtype='<U31')]]
# Hobby a zahrada > Stavby na zahradě > Příslušenství
# [['Roleta RÁKOS NATUR 120 x 180 cm'
#   array(['Hobby a zahrada', 'Stavby na zahradě', 'Ploty',
#          'Zastínění oplocení'], dtype='<U31')            ]]
# Hobby a zahrada > Dům, byt > Koupelna a sanitární technika > Vany, sprchy > Vany
# [['Shower select baterie pod omítku pro 2 spotřebiče, chrom (15748000)'
#   array(['Hobby a zahrada', 'Dům, byt', 'Koupelna a sanitární technika',
#          'Vodovodní baterie', 'Vanové baterie'], dtype='<U31')          ]]

# %%
df.CATEGORY_PATH.str.startswith("Hobby a zahrada > Ruční nářadí").sum()
# Out:
# 37151

# %%
df.CATEGORY_PATH.str.startswith("Hobby a zahrada > Nářadí ruční").sum()
# Out:
# 15651

# %%
new_df[new_df.same == False].tail(50).values
# Out:
# array([[25006, 100054071141,
#         'pilníky jehlové 160 mm v plastovém stojánku, sada 12 dílů, sek 2, NFB 2492 160/2 - PFERD',
#         'pilníky jehlové 160 mm v plastovém stojánku, sada 12 dílů, sek 2, NFB 2492 160/2 - PFERD \t 5 31 17',
#         array([ 5, 31, 17]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Nůžky, nože, pilky'],
#               dtype='<U31')                                             ,
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Nůžky, nože, pilky'],
#               dtype='<U31')                                             ,
#         False, 'Hobby a zahrada > Nářadí ruční > Nůžky, nože, pilky'],
#        [23497, 100023313606,
#         'Rukavice OCS, 60310005, grilovací, originál, žáruvzdorná kůže, 100 % bavlna podšívky, kožený řemínek, 38 x 18,5 cmy,',
#         'Rukavice OCS, 60310005, grilovací, originál, žáruvzdorná kůže, 100 % bavlna podšívky, kožený řemínek, 38 x 18,5 cmy, \t 5 3 28',
#         array([ 5,  3, 28]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Grily, udírny a kotlíky', 'Příslušenství'],
#               dtype='<U31')                                                   ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [27338, 100065014480,
#         'Dřezová nástěnná baterie , 100 mm, s ramínkem trubkovým ø 18 mm - 200 mm, chrom (CB301A01Z)',
#         'Dřezová nástěnná baterie , 100 mm, s ramínkem trubkovým ø 18 mm - 200 mm, chrom (CB301A01Z) \t 5 2 13 14',
#         array([ 5,  2, 13, 14]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Baterie ke dřezům'],
#               dtype='<U31')                                                   ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Kuchyňské baterie'],
#               dtype='<U31')                                                   ,
#         False,
#         'Hobby a zahrada > Dům, byt > Kuchyně > Baterie ke dřezům'],
#        [11662, 100017557460,
#         'Dřezová nástěnná baterie, retro viktorie, 100 mm, s ramínkem trubkovým ø 18 mm - 200 mm (CBL301A)',
#         'Dřezová nástěnná baterie, retro viktorie, 100 mm, s ramínkem trubkovým ø 18 mm - 200 mm (CBL301A) \t 5 2 13 14',
#         array([ 5,  2, 13, 14]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Baterie ke dřezům'],
#               dtype='<U31')                                                   ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Kuchyňské baterie'],
#               dtype='<U31')                                                   ,
#         False,
#         'Hobby a zahrada > Dům, byt > Kuchyně > Baterie ke dřezům'],
#        [12436, 100018927279,
#         "Vodovodní baterie dřezová s flexibilním ramínkem se sprchou sázava, barva: chrom/černá, rozměr: 1/2'', typ ručky: sa006.5/13 (SA006.5/13)",
#         "Vodovodní baterie dřezová s flexibilním ramínkem se sprchou sázava, barva: chrom/černá, rozměr: 1/2'', typ ručky: sa006.5/13 (SA006.5/13) \t 5 2 13 14",
#         array([ 5,  2, 13, 14]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Baterie ke dřezům'],
#               dtype='<U31')                                                   ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Kuchyňské baterie'],
#               dtype='<U31')                                                   ,
#         False,
#         'Hobby a zahrada > Dům, byt > Kuchyně > Baterie ke dřezům'],
#        [1001, 100057094528,
#         'Brusný pás Cubitron II 984F, P60+, šíře 75mm, délka 2000mm, na kovy, se středním a vysokým přítlakem',
#         'Brusný pás Cubitron II 984F, P60+, šíře 75mm, délka 2000mm, na kovy, se středním a vysokým přítlakem \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [22303, 100018927321,
#         "Vodovodní baterie dřezová s flexibilním ramínkem se sprchou sázava, barva: chrom/černá, rozměr: 1/2'', typ ručky: sa306.5/13 (SA306.5/13)",
#         "Vodovodní baterie dřezová s flexibilním ramínkem se sprchou sázava, barva: chrom/černá, rozměr: 1/2'', typ ručky: sa306.5/13 (SA306.5/13) \t 5 2 13 14",
#         array([ 5,  2, 13, 14]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Baterie ke dřezům'],
#               dtype='<U31')                                                   ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Kuchyňské baterie'],
#               dtype='<U31')                                                   ,
#         False,
#         'Hobby a zahrada > Dům, byt > Kuchyně > Baterie ke dřezům'],
#        [15568, 100047560830,
#         '(91394) nůž s rukojetí ve tvaru klíče, 100/60mm, délka otevřeného nože 100mm, délka zavřeného nože 60mm, nerez',
#         '(91394) nůž s rukojetí ve tvaru klíče, 100/60mm, délka otevřeného nože 100mm, délka zavřeného nože 60mm, nerez \t 5 31 17',
#         array([ 5, 31, 17]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Nůžky, nože, pilky'],
#               dtype='<U31')                                             ,
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Nůžky, nože, pilky'],
#               dtype='<U31')                                             ,
#         False, 'Hobby a zahrada > Nářadí ruční > Nůžky, nože, pilky'],
#        [12597, 100047510412,
#         'lepidlo tavné, 4 barvy se třpytkou - červená, žlutá, modrá, zelená 7,5 x 100mm, 20 ks',
#         'lepidlo tavné, 4 barvy se třpytkou - červená, žlutá, modrá, zelená 7,5 x 100mm, 20 ks \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [7707, 100050632656,
#         'Kruh řezaný" loukou "kov a 54 s bf 80( 14), 125 x 1 x 22 mm',
#         'Kruh řezaný" loukou "kov a 54 s bf 80( 14), 125 x 1 x 22 mm \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [8148, 100057091341,
#         'Brusný pás Cubitron II 784F, P60+, šíře 150mm, délka 2000mm, na kovy, se střední mírou přítlaku',
#         'Brusný pás Cubitron II 784F, P60+, šíře 150mm, délka 2000mm, na kovy, se střední mírou přítlaku \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [8062, 100050631310,
#         'Kovové řez kruh a 40 r / s bf l 230 x 22 x 1,6 mm',
#         'Kovové řez kruh a 40 r / s bf l 230 x 22 x 1,6 mm \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [1206, 100018926958,
#         "Vodovodní baterie umyvadlová/dřezová ze stěny pro nízkotlaké ohřívače, barva: chrom, rozměr: připojení 3/8'' vnitřní závit (EM001/21)",
#         "Vodovodní baterie umyvadlová/dřezová ze stěny pro nízkotlaké ohřívače, barva: chrom, rozměr: připojení 3/8'' vnitřní závit (EM001/21) \t 5 2 13 14",
#         array([ 5,  2, 13, 14]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Baterie ke dřezům'],
#               dtype='<U31')                                                   ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Kuchyňské baterie'],
#               dtype='<U31')                                                   ,
#         False,
#         'Hobby a zahrada > Dům, byt > Kuchyně > Baterie ke dřezům'],
#        [10893, 100060300233,
#         'Vyrážeče, různé rozměry - JONNESWAY Varianta: Vyrážeč, rozměr 4x50 mm, délka 150 mm - JONNESWAY M63104',
#         'Vyrážeče, různé rozměry - JONNESWAY Varianta: Vyrážeč, rozměr 4x50 mm, délka 150 mm - JONNESWAY M63104 \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [9929, 100060300180,
#         'Checkpoint Indikátor povolení matic 30 mm horní, pro nákladní auta a autobusy, plast - Dustite LR',
#         'Checkpoint Indikátor povolení matic 30 mm horní, pro nákladní auta a autobusy, plast - Dustite LR \t 5 16 28',
#         array([ 5, 16, 28]),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         False, 'Hobby a zahrada > Ruční nářadí > Příslušenství'],
#        [21400, 100060299724,
#         'Vyrážeče, různé rozměry - JONNESWAY Varianta: Vyrážeč, rozměr 5x55 mm, délka 165 mm - JONNESWAY M63105',
#         'Vyrážeče, různé rozměry - JONNESWAY Varianta: Vyrážeč, rozměr 5x55 mm, délka 165 mm - JONNESWAY M63105 \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [21221, 100058419097,
#         'Sprchový kout obdélníkový, SIMPLE 110x90 cm L/P varianta, rohový vstup včetně sprchové vaničky z litého mramoru',
#         'Sprchový kout obdélníkový, SIMPLE 110x90 cm L/P varianta, rohový vstup včetně sprchové vaničky z litého mramoru \t 5 2 9 36 18',
#         array([ 5,  2,  9, 36, 18]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna, sanitarni technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')               ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna a sanitární technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')                ,
#         False,
#         'Hobby a zahrada > Dům, byt > Koupelna, sanitarni technika > Sprchové kouty > Obdélníkové'],
#        [5888, 100058419188,
#         'Sprchový kout obdélníkový, SIMPLE 110x80 cm L/P varianta, rohový vstup včetně sprchové vaničky z litého mramoru',
#         'Sprchový kout obdélníkový, SIMPLE 110x80 cm L/P varianta, rohový vstup včetně sprchové vaničky z litého mramoru \t 5 2 9 36 18',
#         array([ 5,  2,  9, 36, 18]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna, sanitarni technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')               ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna a sanitární technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')                ,
#         False,
#         'Hobby a zahrada > Dům, byt > Koupelna, sanitarni technika > Sprchové kouty > Obdélníkové'],
#        [14971, 100058419039,
#         'Obdélníkový sprchový kout MELODY R108, 100x80 cm se zalamovacími dveřmi včetně sprchové vaničky z litého mramoru',
#         'Obdélníkový sprchový kout MELODY R108, 100x80 cm se zalamovacími dveřmi včetně sprchové vaničky z litého mramoru \t 5 2 9 36 18',
#         array([ 5,  2,  9, 36, 18]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna, sanitarni technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')               ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna a sanitární technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')                ,
#         False,
#         'Hobby a zahrada > Dům, byt > Koupelna, sanitarni technika > Sprchové kouty > Obdélníkové'],
#        [2268, 100059506425,
#         'Ferdus Bezpečnostní diskové šrouby M12x1.5 koule R13, délka závitu 27,5 mm, klíč 17 / 19',
#         'Ferdus Bezpečnostní diskové šrouby M12x1.5 koule R13, délka závitu 27,5 mm, klíč 17 / 19 \t 5 38 35 52',
#         array([ 5, 38, 35, 52]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Stavební materiál', 'Spojovací materiál',
#                'Šrouby'], dtype='<U31')                                     ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [17942, 100002291067,
#         'Umělý „živý plot“ stínění 95% - výška 150 cm, šíře 3 m, balení 110 ks',
#         'Umělý „živý plot“ stínění 95% - výška 150 cm, šíře 3 m, balení 110 ks \t 5 37 21 48',
#         array([ 5, 37, 21, 48]),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Stavby na zahradě', 'Ploty',
#                'Zastínění oplocení'], dtype='<U31')            , False,
#         'Hobby a zahrada > Ruční nářadí > Příslušenství'],
#        [4525, 100064526144,
#         '915 Flap Disk (Ø115mm, P60) - klapkový kotouč ze 100% zirkonu pro kovy a INOX',
#         '915 Flap Disk (Ø115mm, P60) - klapkový kotouč ze 100% zirkonu pro kovy a INOX \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [8604, 100063786359,
#         '922 k matování nebo k velmi jemnému broušení (Ø150mm, P4000, bez děr) - 2 kusy ',
#         '922 k matování nebo k velmi jemnému broušení (Ø150mm, P4000, bez děr) - 2 kusy  \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Nůžky, nože, pilky'],
#               dtype='<U31')                                             ,
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Nůžky, nože, pilky'],
#        [8623, 100059850807,
#         'Náhradní vyměnitelné čepele - nože pro škrabku, šířka 40 mm, sada 10 ks - ASTA',
#         'Náhradní vyměnitelné čepele - nože pro škrabku, šířka 40 mm, sada 10 ks - ASTA \t 5 31 17',
#         array([ 5, 31, 17]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Nůžky, nože, pilky'],
#               dtype='<U31')                                             ,
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Nůžky, nože, pilky'],
#               dtype='<U31')                                             ,
#         False, 'Hobby a zahrada > Nářadí ruční > Nůžky, nože, pilky'],
#        [14979, 100028628567,
#         'Vodovodní baterie dřezová s flexibilním ramínkem se sprchou colorado, barva: chrom/černá, rozměr: 150 mm (CO202.5/13)',
#         'Vodovodní baterie dřezová s flexibilním ramínkem se sprchou colorado, barva: chrom/černá, rozměr: 150 mm (CO202.5/13) \t 5 2 13 14',
#         array([ 5,  2, 13, 14]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Baterie ke dřezům'],
#               dtype='<U31')                                                   ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Kuchyňské baterie'],
#               dtype='<U31')                                                   ,
#         False,
#         'Hobby a zahrada > Dům, byt > Kuchyně > Baterie ke dřezům'],
#        [2716, 100058419059,
#         'Obdélníkový sprchový kout MELODY 100x90 cm se zalamovacími dveřmi včetně sprchové vaničky z litého mramoru',
#         'Obdélníkový sprchový kout MELODY 100x90 cm se zalamovacími dveřmi včetně sprchové vaničky z litého mramoru \t 5 2 9 36 18',
#         array([ 5,  2,  9, 36, 18]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna, sanitarni technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')               ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna a sanitární technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')                ,
#         False,
#         'Hobby a zahrada > Dům, byt > Koupelna, sanitarni technika > Sprchové kouty > Obdélníkové'],
#        [7735, 100013968425,
#         'Čtvercový sprchový kout MELODY 90x90 cm se zalamovacími dveřmi včetně sprchové vaničky z litého mramoru',
#         'Čtvercový sprchový kout MELODY 90x90 cm se zalamovacími dveřmi včetně sprchové vaničky z litého mramoru \t 5 2 10 36 18',
#         array([ 5,  2, 10, 36, 18]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna a sanitární technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')                ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Koupelna, sanitarni technika',
#                'Sprchové kouty', 'Obdélníkové'], dtype='<U31')               ,
#         False,
#         'Hobby a zahrada > Dům, byt > Koupelna a sanitární technika > Sprchové kouty > Obdélníkové'],
#        [455, 100018926653,
#         "Vodovodní baterie dřezová s flexibilním ramínkem s dvoupolohovým perlátorem amur, barva: chrom/růžová, rozměr: 3/8'' (AM719.0/11R)",
#         "Vodovodní baterie dřezová s flexibilním ramínkem s dvoupolohovým perlátorem amur, barva: chrom/růžová, rozměr: 3/8'' (AM719.0/11R) \t 5 2 13 14",
#         array([ 5,  2, 13, 14]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Baterie ke dřezům'],
#               dtype='<U31')                                                   ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Kuchyňské baterie'],
#               dtype='<U31')                                                   ,
#         False,
#         'Hobby a zahrada > Dům, byt > Kuchyně > Baterie ke dřezům'],
#        [29126, 100050631384,
#         'Kovové řez kruh a 24 s bf 80 l, 300 x 32 x 3 mm',
#         'Kovové řez kruh a 24 s bf 80 l, 300 x 32 x 3 mm \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [2314, 100064526177,
#         '915 Flap Disk (Ø125mm, P60) - klapkový kotouč ze 100% zirkonu pro kovy a INOX',
#         '915 Flap Disk (Ø125mm, P60) - klapkový kotouč ze 100% zirkonu pro kovy a INOX \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [6558, 100056342027,
#         '967A - 65055 kónický Lamelový kotouč Cubitron™ II 125 mm x 22 mm, P 60',
#         '967A - 65055 kónický Lamelový kotouč Cubitron™ II 125 mm x 22 mm, P 60 \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [5526, 100060299981,
#         'Zátka - výpustný šroub olejové vany Ford a PSA, sada 10 ks - ASTA',
#         'Zátka - výpustný šroub olejové vany Ford a PSA, sada 10 ks - ASTA \t 5 38 35 52',
#         array([ 5, 38, 35, 52]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Stavební materiál', 'Spojovací materiál',
#                'Šrouby'], dtype='<U31')                                     ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [26096, 100057094508,
#         'BB-ZB radiální štětinový kotouč, 8 řad lamel, typA, P50, prům. 150 mm, zelený (27605)',
#         'BB-ZB radiální štětinový kotouč, 8 řad lamel, typA, P50, prům. 150 mm, zelený (27605) \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Nůžky, nože, pilky'],
#               dtype='<U31')                                             ,
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Nůžky, nože, pilky'],
#        [24664, 100064453056,
#         '820 Power line (Ø125mm, P800, bez děr) - 5 kusů - autoopravárenský brusný kotouč ',
#         '820 Power line (Ø125mm, P800, bez děr) - 5 kusů - autoopravárenský brusný kotouč  \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [25068, 100064452880,
#         '820 Power line (Ø125mm, P100, bez děr) - 5 kusů - autoopravárenský brusný kotouč ',
#         '820 Power line (Ø125mm, P100, bez děr) - 5 kusů - autoopravárenský brusný kotouč  \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [25257, 100065014444,
#         'Dřezová nástěnná baterie, zuna, 100 mm, s ramínkem plochým rovným 160 mm, chrom (CB302A02Z)',
#         'Dřezová nástěnná baterie, zuna, 100 mm, s ramínkem plochým rovným 160 mm, chrom (CB302A02Z) \t 5 2 13 14',
#         array([ 5,  2, 13, 14]),
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Baterie ke dřezům'],
#               dtype='<U31')                                                   ,
#         array(['Hobby a zahrada', 'Dům, byt', 'Kuchyně', 'Kuchyňské baterie'],
#               dtype='<U31')                                                   ,
#         False,
#         'Hobby a zahrada > Dům, byt > Kuchyně > Baterie ke dřezům'],
#        [21375, 100064453109,
#         '820 Power line (Ø150mm, P120, bez děr) - 5 kusů - autoopravárenský brusný kotouč ',
#         '820 Power line (Ø150mm, P120, bez děr) - 5 kusů - autoopravárenský brusný kotouč  \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [19955, 100064453184,
#         '820 Power line (Ø150mm, P600, 7 děr) - 5 kusů - autoopravárenský brusný kotouč ',
#         '820 Power line (Ø150mm, P600, 7 děr) - 5 kusů - autoopravárenský brusný kotouč  \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [19611, 100036116834,
#         'Safety pack 3 v 1 - NANOFIBER rouška + RUKAVICE + UBROUSEK s alkoholem',
#         'Safety pack 3 v 1 - NANOFIBER rouška + RUKAVICE + UBROUSEK s alkoholem \t 5 27 19 26',
#         array([ 5, 27, 19, 26]),
#         array(['Hobby a zahrada', 'Pracovní výstroj', 'Ochranné pracovní pomůcky',
#                'Respirátory, polomasky', 'Roušky'], dtype='<U31')                 ,
#         array(['Hobby a zahrada', 'Pracovní výstroj', 'Ochranné pracovní pomůcky',
#                'Pracovní rukavice'], dtype='<U31')                                ,
#         False,
#         'Hobby a zahrada > Pracovní výstroj > Ochranné pracovní pomůcky > Respirátory, polomasky > Roušky'],
#        [9315, 100064453114,
#         '820 Power line (Ø150mm, P400, bez děr) - 5 kusů - autoopravárenský brusný kotouč ',
#         '820 Power line (Ø150mm, P400, bez děr) - 5 kusů - autoopravárenský brusný kotouč  \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [12414, 100064453181,
#         '820 Power line (Ø150mm, P360, 7 děr) - 5 kusů - autoopravárenský brusný kotouč ',
#         '820 Power line (Ø150mm, P360, 7 děr) - 5 kusů - autoopravárenský brusný kotouč  \t 5 15 28 8',
#         array([ 5, 15, 28,  8]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Nářadí elektrické', 'Příslušenství', 'Kotouče'],
#               dtype='<U31')                                                        ,
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [14442, 100060299502,
#         'Brusný papír delta 93 mm, různé zrnitosti, 6 otvorů, suchý zip, sada 20 ks - EXTOL PREMIUM Varianta: Brusný papír delta 93 mm, P240, 6 otvorů, suchý zip, sada 20 ks - EXTOL PREMIUM EX8803888',
#         'Brusný papír delta 93 mm, různé zrnitosti, 6 otvorů, suchý zip, sada 20 ks - EXTOL PREMIUM Varianta: Brusný papír delta 93 mm, P240, 6 otvorů, suchý zip, sada 20 ks - EXTOL PREMIUM EX8803888 \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [16438, 100060300402,
#         'Brusný papír delta 93 mm, různé zrnitosti, 6 otvorů, suchý zip, sada 20 ks - EXTOL PREMIUM Varianta: Brusný papír delta 93 mm, P120, 6 otvorů, suchý zip, sada 20 ks - EXTOL-PREMIUM EX8803885',
#         'Brusný papír delta 93 mm, různé zrnitosti, 6 otvorů, suchý zip, sada 20 ks - EXTOL PREMIUM Varianta: Brusný papír delta 93 mm, P120, 6 otvorů, suchý zip, sada 20 ks - EXTOL-PREMIUM EX8803885 \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [14739, 100060300581,
#         'Prodloužení - adaptéry pro hlavice, 6hran 1/4" x 4hran 1/4", různé délky - JONNESWAY Varianta: Prodloužení - adaptér pro hlavice, 6hran 1/4" x 4hran 1/4", 150 mm - JONNESWAY D1150ADP14',
#         'Prodloužení - adaptéry pro hlavice, 6hran 1/4" x 4hran 1/4", různé délky - JONNESWAY Varianta: Prodloužení - adaptér pro hlavice, 6hran 1/4" x 4hran 1/4", 150 mm - JONNESWAY D1150ADP14 \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [24891, 100060300849,
#         'Bity TORX, různé velikosti, úchyt 10 (14) mm, délka 75 mm - JONNESWAY Varianta: Bit TORX, velikost T25, úchyt 10 mm, délka 75 mm - JONNESWAY D175T25',
#         'Bity TORX, různé velikosti, úchyt 10 (14) mm, délka 75 mm - JONNESWAY Varianta: Bit TORX, velikost T25, úchyt 10 mm, délka 75 mm - JONNESWAY D175T25 \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství'],
#        [4910, 100060409818,
#         'Bity RIBE, různé velikosti, úchyt 10 mm, délka 75 mm - JONNESWAY Varianta: Bit RIBE, velikost M12, úchyt 10 mm, délka 75 mm - JONNESWAY D10R75M12A',
#         'Bity RIBE, různé velikosti, úchyt 10 mm, délka 75 mm - JONNESWAY Varianta: Bit RIBE, velikost M12, úchyt 10 mm, délka 75 mm - JONNESWAY D10R75M12A \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Stavební materiál', 'Spojovací materiál',
#                'Šrouby'], dtype='<U31')                                     ,
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False,
#         'Hobby a zahrada > Stavební materiál > Spojovací materiál > Šrouby'],
#        [4909, 100060409818,
#         'Bity RIBE, různé velikosti, úchyt 10 mm, délka 75 mm - JONNESWAY Varianta: Bit RIBE, velikost M12, úchyt 10 mm, délka 75 mm - JONNESWAY D10R75M12A',
#         'Bity RIBE, různé velikosti, úchyt 10 mm, délka 75 mm - JONNESWAY Varianta: Bit RIBE, velikost M12, úchyt 10 mm, délka 75 mm - JONNESWAY D10R75M12A \t 5 16 28',
#         array([ 5, 16, 28]),
#         array(['Hobby a zahrada', 'Stavební materiál', 'Spojovací materiál',
#                'Šrouby'], dtype='<U31')                                     ,
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         False,
#         'Hobby a zahrada > Stavební materiál > Spojovací materiál > Šrouby'],
#        [27683, 100060300173,
#         'Bity RIBE, různé velikosti, úchyt 10 mm, délka 40 mm - JONNESWAY Varianta: Bit RIBE, velikost M13, úchyt 10 mm, délka 40 mm - JONNESWAY D10R40M13A',
#         'Bity RIBE, různé velikosti, úchyt 10 mm, délka 40 mm - JONNESWAY Varianta: Bit RIBE, velikost M13, úchyt 10 mm, délka 40 mm - JONNESWAY D10R40M13A \t 5 16 28',
#         array([ 5, 16, 28]),
#         array(['Hobby a zahrada', 'Stavební materiál', 'Spojovací materiál',
#                'Šrouby'], dtype='<U31')                                     ,
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         False,
#         'Hobby a zahrada > Stavební materiál > Spojovací materiál > Šrouby'],
#        [20941, 100060300111,
#         'Bity RIBE, různé velikosti, úchyt 10 mm, délka 75 mm - JONNESWAY Varianta: Bit RIBE, velikost M5, úchyt 10 mm, délka 75 mm - JONNESWAY D10R75M05A',
#         'Bity RIBE, různé velikosti, úchyt 10 mm, délka 75 mm - JONNESWAY Varianta: Bit RIBE, velikost M5, úchyt 10 mm, délka 75 mm - JONNESWAY D10R75M05A \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Stavební materiál', 'Spojovací materiál',
#                'Šrouby'], dtype='<U31')                                     ,
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False,
#         'Hobby a zahrada > Stavební materiál > Spojovací materiál > Šrouby'],
#        [22017, 100060299528,
#         'Bity Imbus, různé velikosti, úchyt 10 mm, délka 30 mm - JONNESWAY Varianta: Bit Imbus, velikost H8, úchyt 10 mm, délka 30 mm - JONNESWAY D130H80',
#         'Bity Imbus, různé velikosti, úchyt 10 mm, délka 30 mm - JONNESWAY Varianta: Bit Imbus, velikost H8, úchyt 10 mm, délka 30 mm - JONNESWAY D130H80 \t 5 31 28',
#         array([ 5, 31, 28]),
#         array(['Hobby a zahrada', 'Nářadí ruční', 'Příslušenství'], dtype='<U31'),
#         array(['Hobby a zahrada', 'Ruční nářadí', 'Příslušenství'], dtype='<U31'),
#         False, 'Hobby a zahrada > Nářadí ruční > Příslušenství']],
#       dtype=object)

# %%
from fairseq.models.lstm import LSTMModel
model = LSTMModel.from_pretrained(model_name_or_path='/data/data',
                                  checkpoint_file='/data/data/mt-ckpt/checkpoint_best.pt',
                                  data_name_or_path='/data/data/mt-bin'
)

# %%
test_example = model.translate(test.NAME_BRIEF.values, beam=1,verbose=True)
# Out:
# /home/default/lib/python3.8/site-packages/fairseq/search.py:140: UserWarning:
#
# __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#
# /home/default/lib/python3.8/site-packages/fairseq/sequence_generator.py:651: UserWarning:
#
# __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').

# %%
predictions = []
seq = []
for i in test_example:
    sequence = i.split("]")[0].replace("[","").replace("]","").split()
    prediction = label_enc.inverse_transform([int(j) for j in sequence])
    
    seq.append(sequence)
    predictions.append(prediction)

# %%
seq[:10]
# Out:
# [['528', '387', '355', '433'],
#  ['90', '577'],
#  ['327', '426'],
#  ['371', '280'],
#  ['419', '301', '355'],
#  ['334', '257'],
#  ['334', '257'],
#  ['90', '175', '491'],
#  ['523', '201'],
#  ['513', '126']]

# %%
train.to_csv("train_data_seq2seq.csv",index=False)

# %%
test.to_csv("test_data_seq2seq.csv",index=False)

# %%
validation.to_csv("valid_data_seq2seq.csv",index=False)

# %%
test["predictions"]= [" > ".join(i) for i in predictions]

# %%
test["pred_seqs"]= seq

# %%
test.query("CATEGORY_PATH != predictions")
# Out:
#         MATERIAL_ID                                         NAME_BRIEF  \
# 906    100038811702  stropn sušák ; stropn sušák prádl výborn pomoc...
# 37949  100040263921  napínák drátěn plot ocel stříbrn ; tat sad plo...
# 52373       3022275  gril bucket green rozbalit ; gril bucket kompa...
# 53980  100066724714  sprch walk stříbr lesk skl sítotisk ; sprch sa...
# 27009  100049525093  matic nýtovac sad ; matic nýtovac sad ocel oce...
# ...             ...                                                ...
# 11263  100021254305  kbelík čern ; praktick kbelík čern vhodn každ ...
# 19705  100030257853  altán krém textil ; tent prostorn zahradn altá...
# 60994  100050631647  vrták kov tundr hss kobalt válc stopk ; vrták ...
# 16957  100066834977  temp kondel zahradn altánek modr gotan ; mater...
# 18371  100059186163  pláž slunečník zelen ; pláž slunečník vyroben ...
#
#                                                     text  \
# 906    stropn sušák ; stropn sušák prádl výborn pomoc...
# 37949  napínák drátěn plot ocel stříbrn ; tat sad plo...
# 52373  gril bucket green rozbalit ; gril bucket kompa...
# 53980  sprch walk stříbr lesk skl sítotisk ; sprch sa...
# 27009  matic nýtovac sad ; matic nýtovac sad ocel oce...
# ...                                                  ...
# 11263  kbelík čern ; praktick kbelík čern vhodn každ ...
# 19705  altán krém textil ; tent prostorn zahradn altá...
# 60994  vrták kov tundr hss kobalt válc stopk ; vrták ...
# 16957  temp kondel zahradn altánek modr gotan ; mater...
# 18371  pláž slunečník zelen ; pláž slunečník vyroben ...
#
#                CATEGORY_SEQ  \
# 906               [90, 440]
# 37949  [419, 301, 112, 355]
# 52373            [119, 117]
# 53980        [90, 174, 546]
# 27009       [371, 157, 244]
# ...                     ...
# 11263        [90, 214, 215]
# 19705       [523, 398, 418]
# 60994       [241, 355, 499]
# 16957         [419, 66, 23]
# 18371            [523, 397]
#
#                                            CATEGORY_PATH  CATEGORY_ID  \
# 906                          Dům, byt > Sušáky na prádlo           35
# 37949  Stavby na zahradě > Ploty > Gabiony > Přísluše...       157759
# 52373    Grily, udírny a kotlíky > Grily na dřevěné uhlí      1175162
# 53980  Dům, byt > Koupelna a sanitární technika > Zás...      6403678
# 27009            Ruční nářadí > Kleště > Nýtovací kleště     65221461
# ...                                                  ...          ...
# 11263  Dům, byt > Malířské potřeby > Malířské přísluš...       221509
# 19705  Zahradní nábytek > Slunečníky, zastínění > Sta...         5603
# 60994  Nářadí elektrické > Příslušenství > Vrtáky a s...     10262329
# 16957         Stavby na zahradě > Domky, altány > Altány         5603
# 18371                      Zahradní nábytek > Slunečníky          220
#
#                                              predictions        pred_seqs
# 906                   Dům, byt > Šňůry, sušáky na prádlo        [90, 577]
# 37949          Stavby na zahradě > Ploty > Příslušenství  [419, 301, 355]
# 52373            Grily, udírny a kotlíky > Plynové grily       [119, 303]
# 53980  Dům, byt > Koupelna, sanitarni technika > Zást...   [90, 175, 546]
# 27009                Ruční nářadí > Ostatní ruční nářadí       [371, 280]
# ...                                                  ...              ...
# 11263          Stavby na zahradě > Ploty > Příslušenství  [419, 301, 355]
# 19705         Stavby na zahradě > Domky, altány > Altány    [419, 66, 23]
# 60994  Nářadí elektrické > Příslušenství > Vrtáky, sa...  [241, 355, 500]
# 16957  Zahradní nábytek > Slunečníky, zastínění > Sta...  [523, 398, 418]
# 18371  Zahradní nábytek > Slunečníky, zastínění > Slu...  [523, 398, 397]
#
# [9683 rows x 8 columns]

# %%
from sklearn.metrics import f1_score

# %%
f1_score(test.CATEGORY_PATH, test.predictions, average="weighted")
# Out:
# 0.7899187272879282

# %%
label_enc.inverse_transform([int(j) for j in i.strip("[ ]").split()])
# Out:
# array(['Nářadí zahradní', 'Pily'], dtype='<U39')

# %%
i.strip("[ ]").split()
# Out:
# ['243', '290']

# %%
label_enc.inverse_transform([int(i) for i in test_example.strip("[ ]").split()])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-deb99f9160a0> in <module>
# ----> 1 label_enc.inverse_transform([int(i) for i in test_example.strip("[ ]").split()])
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
for i in model.generate(model.encode(example)):
    tokens = [int(i) for i in model.decode(i["tokens"]).strip("[ ]").strip("]").split()]
    print(" > ".join(label_enc.inverse_transform(tokens)))
# Out:
# Nářadí zahradní > Pily
# Ruční nářadí > Ostatní ruční nářadí
# Dílna, stavební technika > Kompresory
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-9bd3068d289e> in <module>
#       1 for i in model.generate(model.encode(example)):
# ----> 2     tokens = [int(i) for i in model.decode(i["tokens"]).strip("[ ]").strip("]").split()]
#       3     print(" > ".join(label_enc.inverse_transform(tokens)))
#
# <ipython-input-37-9bd3068d289e> in <listcomp>(.0)
#       1 for i in model.generate(model.encode(example)):
# ----> 2     tokens = [int(i) for i in model.decode(i["tokens"]).strip("[ ]").strip("]").split()]
#       3     print(" > ".join(label_enc.inverse_transform(tokens)))
#
# ValueError: invalid literal for int() with base 10: '366]'

# %%
label_enc.inverse_transform([int(i) for i in test_example.strip("[ ]").split()])
# Out:
# array(['Nářadí zahradní', 'Pily'], dtype='<U39')
